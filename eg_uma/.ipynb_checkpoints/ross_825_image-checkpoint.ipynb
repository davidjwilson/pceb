# %% [markdown]
# Ross 825 is resolved as a binary in STIS aquistion images https://arxiv.org/pdf/1909.12359.pdf. Can we make this pretty?

# %%
import numpy as np
import matplotlib.pyplot as plt
import astropy.io.fits as fits
import os
import glob
from astropy.table import Table
from astropy.io import ascii
import astropy.units as u
import astropy.constants as const
from matplotlib.colors import LogNorm
import mplcyberpunk


#matplotlib set up
# %matplotlib inline
from matplotlib import rcParams
rcParams["figure.figsize"] = (14, 5)
rcParams["font.size"] = 20

# %%
path = '/media/david/5tb_storage1/lya_15286/hst_data/'
aq1 =  'odg901bdq_raw.fits'

# %%
hdul = fits.open(path+aq1)
hdul.info()
# Out:
# Filename: /media/david/5tb_storage1/lya_15286/hst_data/odg901bdq_raw.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     208   ()
#   1  SCI           1 ImageHDU       105   (100, 100)   int16 (rescales to uint16)
#   2  ERR           1 ImageHDU        54   ()
#   3  DQ            1 ImageHDU        37   ()
#   4  SCI           2 ImageHDU       105   (100, 100)   int16 (rescales to uint16)
#   5  ERR           2 ImageHDU        54   ()
#   6  DQ            2 ImageHDU        37   ()
#   7  SCI           3 ImageHDU       105   (30, 30)   int16 (rescales to uint16)
#   8  ERR           3 ImageHDU        54   ()
#   9  DQ            3 ImageHDU        39   ()

# %%
#plt.style.use("cyberpunk")
for i in [1, 4]:
    image_data = hdul[i].data
   # plt.subplot(121)
    plt.imshow(image_data, cmap='hot', norm=LogNorm(),  vmin=7, vmax=30 )
   # plt.subplot(122)
    #image_hist = plt.hist(image_data.flatten(), 100)
 #   mplcyberpunk.add_glow_effects()
    plt.xlim(25, 80)
    plt.ylim(30, 85)
    plt.yticks(visible=False)
    plt.xticks(visible=False)
    plt.show()

# %% [markdown]
# Can we stack images? http://learn.astropy.org/FITS-images.html

# %%
image_concat = [ hdul[i].data for i in [1,4]]

# %%
final_image = np.sum(image_concat, axis=0)

# %%
plt.imshow(final_image)

# %% [markdown]
# Should have guess aquisition images wouldn't be on top of each other! Just work with one at a time then.

# %%
hdul[1].header
# Out:
# XTENSION= 'IMAGE   '           / extension type
# BITPIX  =                   16 / bits per data value
# NAXIS   =                    2 / number of data axes
# NAXIS1  =                  100 / length of first data axis
# NAXIS2  =                  100 / length of second data axis
# PCOUNT  =                    0 / number of group parameters
# GCOUNT  =                    1 / number of groups
# INHERIT =                    T / inherit the primary header
# EXTNAME = 'SCI     '           / extension name
# EXTVER  =                    1 / extension version number
# ROOTNAME= 'odg901bdq                         ' / rootname of the observation set
# EXPNAME = 'odg901bdq                ' / exposure identifier
# DATAMIN =             0.000000 / the minimum value of the data
# DATAMAX =            86.000000 / the maximum value of the data
# BUNIT   = 'COUNTS            ' / brightness units
# BSCALE  =                  1.0 / scale factor for array value to physical value
# ...
