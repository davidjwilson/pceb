# %% [markdown]
# Looking at FOS data, maybe write a script to turn it into one file if that's reasonable. Also look at IGRNS

# %%
import numpy as np
import matplotlib.pyplot as plt
import astropy.io.fits as fits
import os
import glob
from astropy.table import Table
from astropy.io import ascii
import astropy.units as u
import astropy.constants as const
from astropy.convolution import convolve, Box1DKernel



#matplotlib set up
# %matplotlib inline
from matplotlib import rcParams
rcParams["figure.figsize"] = (14, 5)
rcParams["font.size"] = 20

# %%
path = '/media/david/2tb_ext_hd/hddata/eg_uma/hst/fos/'
# %ls '/media/david/2tb_ext_hd/hddata/eg_uma/hst/fos'
# Out:
# y16u0502t_c0f.fits*  y16u0502t_c7f.fits*  y16u0503t_c4f.fits*
# y16u0502t_c1f.fits*  y16u0502t_cqf.fits*  y16u0503t_c5f.fits*
# y16u0502t_c2f.fits*  y16u0503t_c0f.fits*  y16u0503t_c7f.fits*
# y16u0502t_c4f.fits*  y16u0503t_c1f.fits*  y16u0503t_cqf.fits*
# y16u0502t_c5f.fits*  y16u0503t_c2f.fits*

# %%
calfiles = glob.glob('{}*c*.fits'.format(path))
calfiles
# Out:
# ['/media/david/2tb_ext_hd/hddata/eg_uma/hst/fos/y16u0502t_c0f.fits',
#  '/media/david/2tb_ext_hd/hddata/eg_uma/hst/fos/y16u0502t_c1f.fits',
#  '/media/david/2tb_ext_hd/hddata/eg_uma/hst/fos/y16u0502t_c2f.fits',
#  '/media/david/2tb_ext_hd/hddata/eg_uma/hst/fos/y16u0502t_c4f.fits',
#  '/media/david/2tb_ext_hd/hddata/eg_uma/hst/fos/y16u0502t_c5f.fits',
#  '/media/david/2tb_ext_hd/hddata/eg_uma/hst/fos/y16u0502t_c7f.fits',
#  '/media/david/2tb_ext_hd/hddata/eg_uma/hst/fos/y16u0502t_cqf.fits',
#  '/media/david/2tb_ext_hd/hddata/eg_uma/hst/fos/y16u0503t_c0f.fits',
#  '/media/david/2tb_ext_hd/hddata/eg_uma/hst/fos/y16u0503t_c1f.fits',
#  '/media/david/2tb_ext_hd/hddata/eg_uma/hst/fos/y16u0503t_c2f.fits',
#  '/media/david/2tb_ext_hd/hddata/eg_uma/hst/fos/y16u0503t_c4f.fits',
#  '/media/david/2tb_ext_hd/hddata/eg_uma/hst/fos/y16u0503t_c5f.fits',
#  '/media/david/2tb_ext_hd/hddata/eg_uma/hst/fos/y16u0503t_c7f.fits',
#  '/media/david/2tb_ext_hd/hddata/eg_uma/hst/fos/y16u0503t_cqf.fits']

# %%
rootnames = []
for cal in calfiles:
    rootnames.append(fits.getheader(cal, 0)['ROOTNAME'].lower())
rootnames = np.unique(rootnames)
print(rootnames)
# Out:
# ['y16u0502t' 'y16u0503t']

# %%
fits.getdata(calfiles[0])
# Out:
# array([[-1102.0494, -1100.2944, -1098.5396, ...,  2507.7324,  2509.456 ,
#          2511.1797],
#        [-1102.0494, -1100.2944, -1098.5396, ...,  2507.7324,  2509.456 ,
#          2511.1797],
#        [-1102.0494, -1100.2944, -1098.5396, ...,  2507.7324,  2509.456 ,
#          2511.1797],
#        [-1102.0494, -1100.2944, -1098.5396, ...,  2507.7324,  2509.456 ,
#          2511.1797]], dtype=float32)

# %%
fits.getheader(calfiles[0])
# Out:
# SIMPLE  =                    T / FITS STANDARD
# BITPIX  =                  -32 / FITS BITS/PIXEL
# NAXIS   =                    2 / NUMBER OF AXES
# NAXIS1  =                 2064 /
# NAXIS2  =                    4 /
# EXTEND  =                    T / There maybe standard extensions
# BSCALE  =                1.0E0 / REAL = TAPE*BSCALE + BZERO
# BZERO   =                0.0E0 /
# OPSIZE  =                  832 / PSIZE of original image
# ORIGIN  = 'STScI-STSDAS'       / Fitsio version 21-Feb-1996
# FITSDATE= '2004-02-20'         / Date FITS file was created
# FILENAME= 'y16u0502t_cvt.c0h'  / Original filename
# ALLG-MAX=           2.511180E3 / Data max in all groups
# ALLG-MIN=          -1.102049E3 / Data min in all groups
# ODATTYPE= 'FLOATING'           / Original datatype: Single precision real
# SDASMGNU=                    4 / Number of groups in original image
# CRVAL1  =                   1.
# CRPIX1  =                   1.
# CD1_1   =                   1.
# DATAMIN =          -1.102049E3 / DATA MIN
# DATAMAX =           2.511180E3 / DATA MAX
# RA_APER =          183.9341125
# DEC_APER=       52.51734166667
# FILLCNT =                    0
# ERRCNT  =                    0
# FPKTTIME=      48977.089727786
# LPKTTIME=       48977.08973936
# CTYPE1  = 'PIXEL   '
# APER_POS= 'SINGLE  '
# PASS_DIR=                    0
# YPOS    =                -930.
# YTYPE   = 'OBJ     '
# EXPOSURE=             63.75001
# X_OFFSET=                   0.
# Y_OFFSET=                   0.
# DATE    = '21/12/92           ' / Date FITS file was generated
# IRAF-TLM= '10:31:10 (08/02/2003)' / Time of last modification
# DADSFILE= 'Y16U0502T.D0F'      /
# DADSCLAS= 'CAL     '           /
# DADSDATE= '11-JUN-1994 03:24:17' /
#
#                  / GROUP PARAMETERS: OSS
#
#                  / GROUP PARAMETERS: PODPS
#
#                  / FOS DATA DESCRIPTOR KEYWORDS
# INSTRUME= 'FOS               ' / instrument in use
# ROOTNAME= 'Y16U0502T         ' / rootname of the observation set
# FILETYPE= 'WAV     '           / file type
# BUNIT   = 'ANGSTROMS'          / brightness units
#
#                  / GENERIC CONVERSION KEYWORDS
# HEADER  =                    T / science header line exists
# TRAILER =                    F / reject array exists
# YWRDSLIN=                  516 / science words per packet
# YLINSFRM=                    5 / packets per frame
#
#                  / CALIBRATION FLAGS AND INDICATORS
# GRNDMODE= 'SPECTROSCOPY      ' / ground software mode
# DETECTOR= 'BLUE              ' / detector in use: amber, blue
# APER_ID = 'B-3               ' / aperture id
# POLAR_ID= 'C                 ' / polarizer id
# POLANG  =        0.0000000E+00 / initial angular position of polarizer
# FGWA_ID = 'L15               ' / FGWA id
# FCHNL   =                    0 / first channel
# NCHNLS  =                  512 / number of channels
# OVERSCAN=                    5 / overscan number
# NXSTEPS =                    4 / number of x steps
# YFGIMPEN=                    F / onboard GIMP correction enabled (T/F)
# YFGIMPER= 'NO                ' / error in onboard GIMP correction (YES/NO)
#
#                  / CALIBRATION REFERENCE FILES AND TABLES
# DEFDDTBL=                    F / UDL disabled diode table used
# BACHFILE= 'yref$b3m1128my.r0h' / background header file
# FL1HFILE= 'yref$l7m1416qy.r1h' / first flat-field header file
# FL2HFILE= 'yref$l7m14172y.r1h' / second flat-field header file
# IV1HFILE= 'yref$c3u1343ry.r2h' / first inverse sensitivity header file
# IV2HFILE= 'yref$N/A'           / second inverse sensitivity header file
# RETHFILE= 'yref$N/A'           / waveplate retardation header file
# DDTHFILE= 'yref$c6p1432my.r4h' / disabled diode table header file
# DQ1HFILE= 'yref$b2f1311qy.r5h' / first data quality initialization header file
# DQ2HFILE= 'yref$N/A'           / second data quality initialization header file
# CCG2    = 'mtab$a3d1145ly.cmg' / paired pulse correction parameters
# CCS0    = 'ytab$a3d1145dy.cy0' / aperture parameters
# CCS1    = 'ytab$aaj0732ay.cy1' / aperture position parameters
# CCS2    = 'ytab$a3d1145fy.cy2' / sky emission line regions
# CCS3    = 'ytab$a3d1145gy.cy3' / big and sky filter widths and prism X0
# CCS4    = 'ytab$N/A'           / polarimetry parameters
# CCS5    = 'ytab$a3d1145jy.cy5' / sky shifts
# CCS6    = 'ytab$l611655ty.cy6' / wavelength coefficients
# CCS7    = 'ytab$ba910502y.cy7' / GIMP correction scale factores
# CCS8    = 'ytab$ba31407ly.cy8' / predicted background count rates
#
#                  / CALIBRATION SWITCHES
# CNT_CORR= 'COMPLETE'           / count to count rate conversion
# OFF_CORR= 'COMPLETE'           / GIMP correction
# PPC_CORR= 'COMPLETE'           / paired pulse correction
# BAC_CORR= 'COMPLETE'           / background subtraction
# GMF_CORR= 'COMPLETE'           / scale reference background
# FLT_CORR= 'COMPLETE'           / flat-fielding
# SKY_CORR= 'SKIPPED '           / sky subtraction
# WAV_CORR= 'COMPLETE'           / wavelength scale generation
# FLX_CORR= 'SKIPPED '           / flux scale generation
# ERR_CORR= 'COMPLETE'           / propagated error computation
# MOD_CORR= 'OMIT    '           / ground software mode dependent reductions
#
#                  / PATTERN KEYWORDS
# INTS    =                    2 / number of integrations
# YBASE   =                 -930 / y base
# YRANGE  =                    0 / y range
# YSTEPS  =                    1 / number of y steps
# YSPACE  =        0.0000000E+00 / yrange * 32 / ysteps
# SLICES  =                    1 / number of time slices
# NPAT    =                   25 / number of patterns per readout
# NREAD   =                    4 / number of readouts per memory clear
# NMCLEARS=                    1 / number of memory clears per acquisition
# YSTEP1  = 'OBJ               ' / first ystep data type: OBJ, SKY, BCK, NUL
# YSTEP2  = 'NUL               ' / second ystep data type: OBJ, SKY, BCK, NUL
# YSTEP3  = 'NUL               ' / third ystep data type: OBJ, SKY, BCK, NUL
# XBASE   =                    0 / X-deflection base
# XPITCH  =                 1584 / X-deflection pitch between diode
# YPITCH  =                 1846 / Y-deflection pitch
#
#                  / CALIBRATION KEYWORDS
# LIVETIME=                32640 / accumulator open time  (unit=7.8125 microsec)
# DEADTIME=                 1280 / accumulator close time (unit=7.8125 microsec)
# MAXCLK  =                    0 / maximum clock count
# PA_APER =        0.1188934E+03 / position ang of aperture used with target (deg)
# NOISELM =                65535 / burst noise rejection limit
# OFFS_TAB= 'n/a               ' / GIMP offsets (post-pipeline processing only)
# MINWAVE =             1.163828 / minimum wavelength (angstroms)
# MAXWAVE =              2511.18 / maximum wavelength (angstroms)
#
#                  / STATISTICAL KEYWORDS
# PKTFMT  =                   96 / packet format code
# PODPSFF = '0                 ' / 0=(no podps fill), 1=(podps fill present)
# STDCFFF = '0                 ' / 0=(no st dcf fill), 1=(st dcf fill present)
# STDCFFP = '0000              ' / st dcf fill pattern (hex)
#
#                  / APERTURE POSITION
# RA_APER1=  0.1839341125000E+03 / right ascension of the aperture (deg)
# DECAPER1=  0.5251734166667E+02 / declination of the aperture (deg)
#
#                  / EXPOSURE INFORMATION
# EQUINOX = 'J2000             ' / equinox of the celestial coordinate system
# SUNANGLE=        0.1058799E+03 / angle between sun and V1 axis (deg)
# MOONANGL=        0.8439873E+02 / angle between moon and V1 axis (deg)
# SUN_ALT =        0.2880735E+02 / altitude of the sun above Earth's limb (deg)
# FGSLOCK = 'COARSE            ' / commanded FGS lock (FINE,COARSE,GYROS,UNKNOWN)
#
# DATE-OBS= '21/12/92          ' / UT date of start of observation (dd/mm/yy)
# TIME-OBS= '02:09:12          ' / UT time of start of observation (hh:mm:ss)
# EXPSTART=  0.4897708666066E+05 / exposure start time (Modified Julian Date)
# EXPEND  =  0.4897709896824E+05 / exposure end time (Modified Julian Date)
# EXPTIME =        0.1020000E+04 / exposure duration (seconds)--calculated
# EXPFLAG = 'NORMAL            ' / Exposure interruption indicator
#
#                  / TARGET & PROPOSAL ID
# TARGNAME= 'CASE1             ' / proposer's target name
# RA_TARG =  0.1839341125000E+03 / right ascension of the target (deg) (J2000)
# DEC_TARG=  0.5251734166667E+02 / declination of the target (deg) (J2000)
# PEQUINOX= 'J2000.0           ' / proposed equinox of celestial coordinate system
#
# PROPOSID=                 3816 / PEP proposal identifier
# PEP_EXPO= '7.0200000         ' / PEP exposure identifier including sequence
# LINENUM = '7.020             ' / PEP proposal line number
# SEQLINE = '                  ' / PEP line number of defined sequence
# SEQNAME = '                  ' / PEP define/use sequence name
#
# SCT_CORR= 'OMIT    '
# CCS9    = 'ytab$e3i09491y.cy9'
# APR_CORR= 'COMPLETE'
# AIS_CORR= 'COMPLETE'
# TIM_CORR= 'COMPLETE'
# AISHFILE= 'yref$g2t1439py.r8h'
# CCSA    = 'ytab$g310947py.cya'
# CCSB    = 'ytab$i1n1816gy.cyb'
# CCSC    = 'ytab$g3109483y.cyc'
# CCSD    = 'ytab$g3109487y.cyd'
# PCPHFILE= 'yref$   '
# CYCCSER1= 'ytab$l5u1623cy.cye'
# CYCCSER2= 'ytab$l5u16246y.cye'
# CYCCSER3= 'ytab$l5u1624ay.cye'
# CYCCSER4= 'ytab$l5u1624ey.cye'
# CYCCSER5= 'ytab$l5u1624iy.cye'
# CYCCSER6= 'ytab$l5u1624ny.cye'
# CYCCSER7= 'ytab$l5u1624qy.cye'
# CYCCSER8= 'ytab$l5u16250y.cye'
# CYCCSER9= 'ytab$l5u16255y.cye'
# CYCCSFR = 'ytab$l5u1739ay.cyf'
# HISTORY   FL1HFILE=yref$l7m1416qy.r1h       FLT_CORR=COMPLETE
# HISTORY   INFLIGHT  01/01/1992
# HISTORY   Superflux-derived FOS closeout flatfield
# HISTORY   AISHFILE=yref$g2t1439py.r8h       AIS_CORR=COMPLETE
# HISTORY   INFLIGHT 24/4/90 - 15/12/93
# HISTORY   MAJOR photom system update: pre-costar AIS time+aper-depend flux cal
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# CTYPE2  = 'GROUP_NUMBER'       / Extra dimension axis name
# CD2_2   =                    1 /
# CD2_1   =                    0 /
# CD1_2   =                    0 /

# %%
for rootname in rootnames:
    w = fits.getdata('{}{}_c0f.fits'.format(path, rootname))[0]
    f = fits.getdata('{}{}_c1f.fits'.format(path, rootname))[0]
    e = fits.getdata('{}{}_c2f.fits'.format(path, rootname))[0]
    q = fits.getdata('{}{}_cqf.fits'.format(path, rootname))[0]
    plt.plot(w[q<200],f[q<200])  
    # plt.plot(w[q<200],e[q<200])  
    # plt.show()
    # plt.plot(w, q)
    # plt.show()

# %%
mglines = [2796.35, 2803.53]

plt.figure(figsize=(8,5))
for rootname in rootnames[1:2]:
    w = fits.getdata('{}{}_c0f.fits'.format(path, rootname))[0]
    f = fits.getdata('{}{}_c1f.fits'.format(path, rootname))[0]
    e = fits.getdata('{}{}_c2f.fits'.format(path, rootname))[0]
    q = fits.getdata('{}{}_cqf.fits'.format(path, rootname))[0]
    plt.step(w[q<200],f[q<200], where='mid')
    plt.errorbar(w[q<200], f[q<200], yerr=e[q<200], ls='none', c='C0', alpha =0.5)
[plt.axvline(line, ls='--', c='C2') for line in mglines]    
plt.xlim(2775, 2825)
plt.ylim(2.7e-14, 4.3e-14)
# Out:
# (2.7e-14, 4.3e-14)

# %%
#compare with cos?

smooth =2
for rootname in rootnames[0:1]:
    w = fits.getdata('{}{}_c0f.fits'.format(path, rootname))[0]
    f = fits.getdata('{}{}_c1f.fits'.format(path, rootname))[0]
    e = fits.getdata('{}{}_c2f.fits'.format(path, rootname))[0]
    q = fits.getdata('{}{}_cqf.fits'.format(path, rootname))[0]
    f = convolve(f,Box1DKernel(smooth))
    e = convolve(e,Box1DKernel(smooth))/(smooth**0.5)
    plt.plot(w[q<200],f[q<200])  

cpath = '/media/david/2tb_ext_hd/hddata/eg_uma/hst/cos/'
x = glob.glob('{}*x1dsum.fits'.format(cpath))[0]

smooth=5
data = fits.getdata(x, 1)
w = np.array([], dtype=float)
f = np.array([], dtype=float)
e = np.array([], dtype=float)
for dt in data[::-1]:
    wi, fi, ei, dq = dt['WAVELENGTH'], dt['FLUX'], dt['ERROR'], dt['DQ']
    mask = (fi>0) & (dq == 0) & (wi < 1213) | (wi > 1217) & (fi>0) & (dq == 0) 
   # mask = (dq==0)
    wi, fi, ei = wi[mask], fi[mask], ei[mask]
    w = np.concatenate((w, wi))
    f = np.concatenate((f, fi))
    e = np.concatenate((e, ei)) 

f = convolve(f,Box1DKernel(smooth))
e = convolve(e,Box1DKernel(smooth))/(smooth**0.5)
plt.plot(w,f, zorder=-1)

# %% [markdown]
# IGRNS

# %%
hdata = Table.read('../igrins/spectra/eg_uma_H_20190319_smoothed.ecsv')
kdata = Table.read('../igrins/spectra/eg_uma_K_20190319_smoothed.ecsv')

# %%
wh, fh, eh = hdata['WAVELENGTH'], hdata['FLUX'], hdata['ERROR']
wk, fk, ek = kdata['WAVELENGTH'], kdata['FLUX'], kdata['ERROR']

hcut = [6000, 31000]
kcut = [8000, 31000]

wh, fh, eh = wh[hcut[0]:hcut[1]], fh[hcut[0]:hcut[1]], eh[hcut[0]:hcut[1]]
wk, fk, ek = wk[kcut[0]:kcut[1]], fk[kcut[0]:kcut[1]], ek[kcut[0]:kcut[1]]

# %%
# plt.plot(wh, fh) 
plt.plot(wk, fk)
# plt.ylim(0, 1000000)

# %%
tpath = []
