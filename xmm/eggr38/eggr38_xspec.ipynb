# %%
import numpy as np
import matplotlib.pyplot as plt
import astropy.io.fits as fits
import os
import glob
from astropy.table import Table
from astropy.io import ascii

import astropy.units as u
from astropy import time, coordinates as coord
import astropy.constants as const
from astropy.modeling import models, fitting


#matplotlib set up
# %matplotlib inline
from matplotlib import rcParams
rcParams["figure.figsize"] = (14, 5)
rcParams["font.size"] = 20

# %%
from xspec import *

# %%
s = Spectrum("src_spectrum_bin25.ds")
# Out:
# 1 spectrum  in use
#
# Spectral Data File: src_spectrum_bin25.ds  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  1.608e-01 +/- 3.042e-03 (90.3 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-114
#   Telescope: XMM Instrument: EPIC  Channel Type: PI
#   Exposure Time: 1.975e+04 sec
#  Using fit statistic: chi
#  Using Background File                bkg_spectrum_grp.ds
#   Background Exposure Time: 1.975e+04 sec
#  Using Response (RMF) File            response_grp.rmf for Source 1

# %%
# Model("phabs*apec")
# Fit.perform()
# Plot.device = "/xs"
# Plot("data")

# %%
Plot.device = '/null'
Plot('data')

# %%
# # s.ignore('bad')
# Plot.xAxis='angstrom'
# s.ignore('5.0-60.0')
# Plot.perHz=False
# Plot.area=True
# Plot('data')
# wave = Plot.x()
# rates = Plot.y()
# bins = Plot.xErr()
# error = Plot.yErr()
# folded = Plot.model()

# %%
# plt.errorbar(wave, rates, xerr=bins, yerr=error, ls='none')

# %%
mod = Model('apec*phabs', setPars={1:1, 2:0.4, 5:1e-3})
mod.phabs.nH.frozen = True
# Out:
# ========================================================================
# Model apec<1>*phabs<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   apec       kT         keV      1.00000      +/-  0.0
#    2    1   apec       Abundanc            1.00000      frozen
#    3    1   apec       Redshift            0.0          frozen
#    4    1   apec       norm                1.00000      +/-  0.0
#    5    2   phabs      nH         10^22    1.00000      +/-  0.0
# ________________________________________________________________________
#
# Reading APEC data from 3.0.9
#
#
# Fit statistic  : Chi-Squared              2.581231e+10     using 114 bins.
#
# Test statistic : Chi-Squared              2.581231e+10     using 114 bins.
#  Null hypothesis probability of 0.000000e+00 with 111 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              2.995313e+11     using 114 bins.
#
# Test statistic : Chi-Squared              2.995313e+11     using 114 bins.
#  Null hypothesis probability of 0.000000e+00 with 111 degrees of freedom
#  Current data and model not fit yet.
#
# ========================================================================
# Model apec<1>*phabs<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   apec       kT         keV      1.00000      +/-  0.0
#    2    1   apec       Abundanc            0.400000     frozen
#    3    1   apec       Redshift            0.0          frozen
#    4    1   apec       norm                1.00000      +/-  0.0
#    5    2   phabs      nH         10^22    1.00000E-03  +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              2.995313e+11     using 114 bins.
#
# Test statistic : Chi-Squared              2.995313e+11     using 114 bins.
#  Null hypothesis probability of 0.000000e+00 with 112 degrees of freedom
#  Current data and model not fit yet.

# %%
Fit.perform()
# Out:
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:kT        4:norm
# 1036.43      186.068      -3      0.896066   7.24006e-05
# 1030.22      275067       -4      0.861076   7.23937e-05
# 1029.24      1876.41      -5      0.851858   7.20045e-05
# 1029.02      12023.4      -6      0.845113   7.18079e-05
# 1029.02      135.936      -7      0.845094   7.18079e-05
# ==============================
#  Variances and Principal Axes
#                  1        4
#  2.7007E-12| -0.0000   1.0000
#  2.1803E-04|  1.0000   0.0000
# ------------------------------
#
# ========================
#   Covariance Matrix
#         1           2
#    2.180e-04   8.670e-09
#    8.670e-09   3.046e-12
# ------------------------
#
# ========================================================================
# Model apec<1>*phabs<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   apec       kT         keV      0.845094     +/-  1.47657E-02
#    2    1   apec       Abundanc            0.400000     frozen
#    3    1   apec       Redshift            0.0          frozen
#    4    1   apec       norm                7.18079E-05  +/-  1.74514E-06
#    5    2   phabs      nH         10^22    1.00000E-03  frozen
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 1029.02     using 114 bins.
#
# Test statistic : Chi-Squared                 1029.02     using 114 bins.
#  Null hypothesis probability of 4.19e-148 with 112 degrees of freedom

# %%
# s.ignore('bad')
Plot.xAxis='angstrom'
s.ignore('**-5.0 60.0-**')

mod = Model('phabs*(apec+apec)', setPars={1:1e-3, 2:0.5,3:0.4,6:2.0, 7:0.4})
# mod.phabs.nH.frozen = True
# mod.apec.Abundanc.frozen = False
# mod.apec_3.Abundanc.frozen = False


Fit.perform()


# Plot.setRebin(minSig=3, maxBins=10, groupNum=1, errType='quad')

Plot.perHz=False
Plot.area=True
Plot('data')

wave = Plot.x()
rates = Plot.y()
bins = Plot.xErr()
error = Plot.yErr()
folded = Plot.model()
# Out:
#      7 channels (108-114) ignored in spectrum #     1
#      1 channels (1) ignored in spectrum #     1
#
# Fit statistic  : Chi-Squared                  121.37     using 106 bins.
#
# Test statistic : Chi-Squared                  121.37     using 106 bins.
#  Null hypothesis probability of 8.18e-02 with 101 degrees of freedom
#  Current data and model not fit yet.
#
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      1.00000      +/-  0.0
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              9.646997e+10     using 106 bins.
#
# Test statistic : Chi-Squared              9.646997e+10     using 106 bins.
#  Null hypothesis probability of 0.000000e+00 with 101 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              4.929896e+11     using 106 bins.
#
# Test statistic : Chi-Squared              4.929896e+11     using 106 bins.
#  Null hypothesis probability of 0.000000e+00 with 101 degrees of freedom
#  Current data and model not fit yet.
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000E-03  +/-  0.0
#    2    2   apec       kT         keV      0.500000     +/-  0.0
#    3    2   apec       Abundanc            0.400000     frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      2.00000      +/-  0.0
#    7    3   apec       Abundanc            0.400000     frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm          6:kT        9:norm
# 283.688      176507        0   6.28145e-05      0.458844   6.88230e-05       1.47748   7.56379e-05
# 192.105      96962.9      -1   3.12003e-05      0.342568   6.69418e-05       1.27639   7.86477e-05
# 140.402      426777       -2    0.00531817      0.253198   9.29117e-05       1.18180   7.63809e-05
# 122.039      134836       -3    0.00936997      0.269974   9.68506e-05       1.14255   7.57091e-05
# 121.336      1842.15      -4     0.0101920      0.268197   9.72457e-05       1.12366   7.49196e-05
# 121.312      1304.63      -5     0.0102887      0.267400   9.71079e-05       1.11943   7.48967e-05
# 121.312      4.29274      -6     0.0102834      0.267403   9.71022e-05       1.11943   7.48962e-05
# ============================================================
#  Variances and Principal Axes
#                  1        2        5        6        9
#  4.9871E-12| -0.0006   0.0001   0.5405  -0.0001   0.8413
#  1.9327E-11| -0.0008  -0.0001   0.8413   0.0000  -0.5405
#  2.4024E-05| -0.8213  -0.5661  -0.0008   0.0702   0.0001
#  9.2149E-05|  0.5700  -0.8093   0.0006   0.1421   0.0002
#  8.1374E-04|  0.0236  -0.1567  -0.0000  -0.9874  -0.0000
# ------------------------------------------------------------
#
# ============================================================
#   Covariance Matrix
#         1           2           3           4           5
#    4.660e-05  -3.434e-05   4.739e-08  -1.287e-05   7.248e-09
#   -3.434e-05   8.804e-05  -3.197e-08   1.144e-04  -1.012e-08
#    4.739e-08  -3.197e-08   6.416e-11   1.226e-08   1.766e-12
#   -1.287e-05   1.144e-04   1.226e-08   7.953e-04   2.451e-08
#    7.248e-09  -1.012e-08   1.766e-12   2.451e-08   1.260e-11
# ------------------------------------------------------------
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.02834E-02  +/-  6.82614E-03
#    2    2   apec       kT         keV      0.267403     +/-  9.38281E-03
#    3    2   apec       Abundanc            0.400000     frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                9.71022E-05  +/-  8.00973E-06
#    6    3   apec       kT         keV      1.11943      +/-  2.82006E-02
#    7    3   apec       Abundanc            0.400000     frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                7.48962E-05  +/-  3.54928E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  121.31     using 106 bins.
#
# Test statistic : Chi-Squared                  121.31     using 106 bins.
#  Null hypothesis probability of 8.24e-02 with 101 degrees of freedom

# %%
plt.errorbar(wave, rates, xerr=bins, yerr=error, ls='none')
# plt.step(wave, rates, where='mid')
plt.plot(wave, folded)

# %%
# s.ignore('bad')
Plot.xAxis='angstrom'
s.ignore('**-5.0 60.0-**')

mod = Model('phabs*(apec+apec)', setPars={1:1e-3, 2:0.5,3:0.4,6:2.0, 7:0.4})
# mod.phabs.nH.frozen = True
# mod.apec.Abundanc.frozen = False
# mod.apec_3.Abundanc.frozen = False

AllModels.setEnergies("0.3 10")
Fit.perform()
flux = AllModels.calcFlux(".3 10 err")
print(flux)


# Plot.setRebin(minSig=3, maxBins=10, groupNum=1, errType='quad')

Plot.perHz=False
Plot.area=True
Plot('data')

wave = Plot.x()
rates = Plot.y()
bins = Plot.xErr()
error = Plot.yErr()
folded = Plot.model()
plt.errorbar(wave, rates, xerr=bins, yerr=error, ls='none')
# plt.step(wave, rates, where='mid')
plt.plot(wave, folded)

flux = AllModels.calcFlux(".3 10 err")
print(flux)
# Out:
#      7 channels (108-114) ignored in spectrum #     1
#      1 channels (1) ignored in spectrum #     1
#
# Fit statistic  : Chi-Squared                  131.75     using 106 bins.
#
# Test statistic : Chi-Squared                  131.75     using 106 bins.
#  Null hypothesis probability of 2.16e-02 with 101 degrees of freedom
#  Current data and model not fit yet.
#
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      1.00000      +/-  0.0
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apNone
# ec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              9.643163e+10     using 106 bins.
#
# Test statistic : Chi-Squared              9.643163e+10     using 106 bins.
#  Null hypothesis probability of 0.000000e+00 with 101 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              4.842445e+11     using 106 bins.
#
# Test statistic : Chi-Squared              4.842445e+11     using 106 bins.
#  Null hypothesis probability of 0.000000e+00 with 101 degrees of freedom
#  Current data and model not fit yet.
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000E-03  +/-  0.0
#    2    2   apec       kT         keV      0.500000     +/-  0.0
#    3    2   apec       Abundanc            0.400000     frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      2.00000      +/-  0.0
#    7    3   apec       Abundanc            0.400000     frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Models will now use energy array created from:
#    0.3 - 10   1000 linear bins
#
#
# Fit statistic  : Chi-Squared              4.842445e+11     using 106 bins.
#
# Test statistic : Chi-Squared              4.842445e+11     using 106 bins.
#  Null hypothesis probability of 0.000000e+00 with 101 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:nH          2:kT        5:norm          6:kT        9:norm
# 307.587      177184        0   0.000333868      0.456776   6.87301e-05       1.49593   7.59494e-05
# 252.288      102780       -1   6.08331e-05      0.345871   6.12030e-05       1.29244   7.74426e-05
# 157.874      683126       -2   6.04307e-06      0.259467   8.34794e-05       1.19648   7.47366e-05
# 133.142      338177       -3   1.68070e-06      0.274712   8.90051e-05       1.14645   7.41657e-05
# 132.685      47790.8      -4   2.57289e-07      0.272464   8.79271e-05       1.12898   7.33924e-05
# 131.852      67889.2      -1    0.00173020      0.268490   9.15132e-05       1.12071   7.40716e-05
# 131.777      5473.47      -1   0.000670378      0.268130   9.06468e-05       1.11956   7.38221e-05
# 131.753      1895.3       -1   2.34364e-06      0.268384   9.00248e-05       1.11920   7.37141e-05
# 131.753      1297.36       0   4.63123e-07      0.268417   8.99444e-05       1.11918   7.36964e-05
# ============================================================
#  Variances and Principal Axes
#                  1        2        5        6        9
#  4.6231E-12| -0.0005   0.0001   0.5623  -0.0001   0.8270
#  1.7839E-11| -0.0007  -0.0001   0.8270   0.0000  -0.5623
#  3.4125E-05| -0.6524  -0.7508  -0.0006   0.1028   0.0001
#  1.3658E-04|  0.7567  -0.6379   0.0007   0.1430   0.0002
#  8.0749E-04|  0.0418  -0.1711   0.0000  -0.9844  -0.0000
# ------------------------------------------------------------
#
# ============================================================
#   Covariance Matrix
#         1           2           3           4           5
#    9.414e-05  -5.498e-05   8.121e-08  -2.071e-05   1.368e-08
#   -5.498e-05   9.847e-05  -4.405e-08   1.209e-04  -1.256e-08
#    8.121e-08  -4.405e-08   8.444e-11   5.836e-09   6.453e-12
#   -2.071e-05   1.209e-04   5.836e-09   7.856e-04   2.362e-08
#    1.368e-08  -1.256e-08   6.453e-12   2.362e-08   1.304e-11
# ------------------------------------------------------------
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    4.63123E-07  +/-  9.70249E-03
#    2    2   apec       kT         keV      0.268417     +/-  9.92308E-03
#    3    2   apec       Abundanc            0.400000     frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                8.99444E-05  +/-  9.18902E-06
#    6    3   apec       kT         keV      1.11918      +/-  2.80284E-02
#    7    3   apec       Abundanc            0.400000     frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                7.36964E-05  +/-  3.61070E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  131.75     using 106 bins.
#
# Test statistic : Chi-Squared                  131.75     using 106 bins.
#  Null hypothesis probability of 2.16e-02 with 101 degrees of freedom
# Spectrum 1: Upper range bound           10 reset by matrix bound to           10
# Parameter distribution is derived from fit covariance matrix.
#  Model Flux 0.0001663 photons (1.87e-13 ergs/cm^2/s) range (0.30000 - 10.000 keV)
#      Error range 0.0001544 - 0.0001665    (1.761e-13 - 1.881e-13)  (68.00% confidence)
# None
# Spectrum 1: Upper range bound           10 reset by matrix bound to           10
# Parameter distribution is derived from fit covariance matrix.
#  Model Flux 0.0001663 photons (1.87e-13 ergs/cm^2/s) range (0.30000 - 10.000 keV)
#      Error range 0.0001552 - 0.0001670    (1.770e-13 - 1.887e-13)  (68.00% confidence)

# %%
flux = AllModels.calcFlux(".3 10 err")
print(flux)
# Out:
# Spectrum 1: Upper range bound           10 reset by matrix bound to           10
# NoneParameter distribution is derived from fit covariance matrix.
#  Model Flux 0.0001663 photons (1.87e-13 ergs/cm^2/s) range (0.30000 - 10.000 keV)
#      Error range 0.0001564 - 0.0001665    (1.770e-13 - 1.885e-13)  (68.00% confidence)

# %%
s.flux
# Out:
# (1.8699871054245658e-13,
#  1.770236138536613e-13,
#  1.8847416256346974e-13,
#  0.00016630192792586754,
#  0.00015635778302308632,
#  0.00016645113071537613)

# %%
fx, fxel, fxeu = s.flux[0]*u.erg/u.cm**2/u.s, (s.flux[0]-s.flux[1])*u.erg/u.cm**2/u.s, (s.flux[2]-s.flux[0])*u.erg/u.cm**2/u.s  
d = (1000/23.39160255904337)*u.pc
p = 0.56*u.d
lstar = (10**-2.5)*u.Lsun
lx = (fx*(d.to(u.cm))**2).to(u.Lsun)
lx_star = lx/lstar
print(lx_star)
lx_star_err =  np.array(lx_star*[fxel/fx, fxeu/fx])
print(lx_star_err)
# Out:
# 0.0002688114852681345
# [1.43392462e-05 2.12096890e-06]

# %%
path = '/media/david/2tb_ext_hd/hddata/carmenes_binary/xraycat/'
xraycat = fits.open('{}J_ApJ_743_48_catalog.dat.fits'.format(path))

# %%
xraydata = xraycat[1].data
plt.figure(figsize=(7, 5))
plt.scatter(xraydata['Prot'], 10**xraydata['Lx/bol'], marker='o', alpha=0.5)
plt.xscale('log')
plt.yscale('log')
porb = 0.60417356
porb_e = 0.00000025
# plt.errorbar(porb, lx_strar, yerr=[[lx_r_e[0]], [lx_r_e[1]]], marker='o', ls='none', c='C1', markeredgecolor='k')
plt.errorbar(p, lx_star, yerr= [[lx_star_err[0]],[lx_star_err[1]]], marker='o', c='C1', markeredgecolor='k')
plt.xlabel('Porb (d)')
plt.ylabel('R$_{\mathrm{x}}$')
plt.tight_layout()
# plt.savefig('plots/Rx.png', dpi=150, facecolor='w')
# plt.savefig('plots/Rx.pdf', dpi=150, facecolor='w')

# %% [markdown]
# To do- double check spectral type, lightcurve.

# %%
plt.figure(figsize=(12, 6))
plt.errorbar(wave, rates, xerr=bins, yerr=error, ls='none')
# plt.step(wave, rates, where='mid')
plt.plot(wave, folded)
plt.xlabel('Wavelength (\AA)')
plt.ylabel('Counts (s$^{-1}$ cm$^{-2}$ \AA$^{-1}$)')
plt.tight_layout()
plt.savefig('../plots/eggr-38_xmm_spec.png', facecolor='w')

# %%
# #quick sed
# wc, fc, ec, dq = np.loadtxt('../../hst_spectra/eggr_38_COS_FUV_1291_2018-02-27.dat', unpack=True)

# #uv
# plt.plot(wc[(dq==0) & (fc > 0)], fc[(dq==0) & (fc > 0)])

# #xray
# mx  = folded * (u.photon/u.s/u.cm**2/u.AA).to(u.erg/u.s/u.cm**2/u.AA, equivalencies=u.spectral_density(wave*u.AA))
# plt.plot(wave, mx)

# #uves
# upath = '/media/david/2tb_ext_hd/hddata/pcebs/optical/eggr_38_uves/'
# uspecs = glob.glob('{}*.fits'.format(upath))
# for spec in uspecs[:2]:
#     data = fits.getdata(spec, 1)[0]
#     plt.plot(data['WAVE'][data['FLUX'] > 0], data['FLUX'][data['FLUX'] > 0]*1e-16)

# #model
# mw, mf = np.loadtxt('../../models/EGGR-38_07010.dk', skiprows=40, unpack=True)
# plt.plot(mw, mf/(np.max(mf)/np.max(fc))*0.2)

# plt.xscale('log')
# plt.yscale('log')

# #bit rubbish
