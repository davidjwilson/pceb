# %%
import numpy as np
import matplotlib.pyplot as plt
import astropy.io.fits as fits
import os
import glob
from astropy.table import Table
from astropy.io import ascii

import astropy.units as u
from astropy import time, coordinates as coord
import astropy.constants as const
from astropy.modeling import models, fitting


#matplotlib set up
# %matplotlib inline
from matplotlib import rcParams
rcParams["figure.figsize"] = (14, 5)
rcParams["font.size"] = 20

# %%
from xspec import *
Plot.device = '/null'

# %%
glob.glob('*src_spectrum_bin10*')
# Out:
# ['v727car_src_spectrum_bin10.ds',
#  'src_spectrum_bin10.ds',
#  'wd2317+268_src_spectrum_bin10.ds',
#  'wd1448_171_src_spectrum_bin10.ds',
#  'wd1458+171_src_spectrum_bin10.ds',
#  'wd1504+546_src_spectrum_bin10.ds',
#  'wd1436-216_src_spectrum_bin10.ds']

# %%
stars = ['uzsex', 'eguma', 'eggr38', 'wd1436-216', 'wd1458+171','wd1504+546', 'v727car']
specbins = [25, 25, 25, 25, 10, 10, 10]

# %%
# # napec = [] #number of apec models that give the best fit to each star  - doesn't work, need to do it manually

# for i, star in enumerate(stars):
#     print(star)
    
#     s = Spectrum('{}_src_spectrum_bin{}.ds'.format(star, specbins[i]), backFile='{}_bkg_spectrum_grp.ds'.format(star), 
#                  respFile='{}_response_grp.rmf'.format(star), arfFile='{}_EMOS1.arf'.format(star))
#     s.background = '{}_bkg_spectrum_grp.ds'.format(star)
#     s.response = '{}_response_grp.rmf'.format(star)
#     s.response.arf = '{}_EMOS1.arf'.format(star)
    
#     Plot('data')
#     Plot.xAxis='angstrom'
#     s.ignore('**-5.0 60.0-**')
    

     
#     Plot.perHz=False
#     Plot.area=True
#     Plot('data')

#     wave = Plot.x()
#     rates = Plot.y()
#     bins = Plot.xErr()
#     error = Plot.yErr()
    
#     plt.errorbar(wave, rates, xerr=bins, yerr=error, ls='none')
#     # plt.errorbar(wave, rates)
    
#     mod = Model('apec*phabs', setPars={1:0.5, 2:0.4, 5:1e-3})
#     mod.phabs.nH.frozen = True
#     Fit.renorm()
#     Fit.perform()
#     Plot('data')
#     folded = Plot.model()
#     plt.step(wave, folded, where='mid')
#     stat1 = Fit.statistic
    
    
    
#     mod2 = Model('phabs*(apec+apec)', setPars={1:1e-3, 2:1,3:0.4,6:1, 7:0.4})
#     mod2.phabs.nH.frozen = True
#     Fit.renorm()
#     Fit.perform()
#     Plot('data')
#     folded = Plot.model()
#     plt.step(wave, folded, where='mid')

#     plt.show()
#     stat2 = Fit.statistic
    
# #     if stat2 < stat1:
# #         napec.append(2)
# #     else:
# #         napec.append(1)
    
#     # print('here', Fit.statistic)
    
    
#     DataManager.clear(s)
    
# print(napec)

# %%
napec = [2,2,2,2,1,1,1]
fluxes = []
fluxes_eu = []
fluxes_el = []


for i, star in enumerate(stars):
    print(star)
    
    s = Spectrum('{}_src_spectrum_bin{}.ds'.format(star, specbins[i]), backFile='{}_bkg_spectrum_grp.ds'.format(star), respFile='{}_response_grp.rmf'.format(star))#, arfFile='{}_EMOS1.arf'.format(star))
    # s.background = '{}_bkg_spectrum_grp.ds'.format(star)
    # s.response = '{}_response_grp.rmf'.format(star)
    # # s.response.arf = '{}_EMOS1.arf'.format(star)
    
    Plot('data')
    Plot.xAxis='angstrom'
    s.ignore('**-5.0 60.0-**')
    

     
    Plot.perHz=False
    Plot.area=True
    Plot('data')

    wave = Plot.x()
    rates = Plot.y()
    bins = Plot.xErr()
    error = Plot.yErr()
    

        
    
    plt.errorbar(wave, rates, xerr=bins, yerr=error, ls='none')
    AllModels.setEnergies("0.1 2.4")


    # plt.errorbar(wave, rates)
    if napec[i] == 1:
        mod = Model('apec*phabs', setPars={1:1, 2:0.4, 5:1e-4})
        mod.phabs.nH.frozen = True
        Fit.renorm()
        Fit.perform()
        Plot('data')
        folded = Plot.model()
        plt.plot(wave, folded)

    
    else:
    
        mod2 = Model('phabs*(apec+apec)', setPars={1:1e-4, 2:1,3:0.4,6:0.5, 7:0.4})
        mod2.phabs.nH.frozen = True
        Fit.renorm()
        Fit.perform()
        Plot('data')
        folded = Plot.model()
        plt.plot(wave, folded)

        
    if star == 'eguma':
        eguma_wave = np.array(wave)
        eguma_rates = np.array(rates)
        eguma_bins = np.array(bins)
        eguma_error= np.array(error)
        eguma_folded = np.array(folded)
        
    flux = AllModels.calcFlux("0.1 2.4 err")
    print(flux)
    plt.show()
    # s.flux[0]*u.erg/u.cm**2/u.s, (s.flux[0]-s.flux[1])*u.erg/u.cm**2/u.s, (s.flux[2]-s.flux[0])*u.erg/u.cm**2/u.s  
    
    fluxes.append(s.flux[0])
    fluxes_eu.append(s.flux[2]-s.flux[0])
    fluxes_el.append(s.flux[0]-s.flux[1])
    
    
    DataManager.clear(s)
    
# print(napec)
# Out:
# uzsex
#
# 1 spectrum  in use
#
# Spectral Data File: uzsex_src_spectrum_bin25.ds  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  1.425e-02 +/- 1.830e-03 (44.6 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-14
#   Telescope: XMM Instrument: EPIC  Channel Type: PI
#   Exposure Time: 1.109e+04 sec
#  Using fit statistic: chi
#  Using Background File                bkg_spectrum_grp.ds
#   Background Exposure Time: 1.002e+04 sec
#  Using Response (RMF) File            response_grp.rmf for Source 1
#
#
# Fit statistic  : Chi-Squared                  124.55     using 14 bins.
#
# Test statistic : Chi-Squared                  124.55     using 14 bins.
#  Null hypothesis probability of 7.61e-21 with 12 degrees of freedom
#  Current data and model not fit yet.
# Net count rate (cts/s) for Spectrum:1  1.977e-02 +/- 1.779e-03 (61.9 % total)
#
# Fit statistic  : Chi-Squared                   78.38     using 14 bins.
#
# Test statistic : Chi-Squared                   78.38     using 14 bins.
#  Null hypothesis probability of 8.39e-12 with 12 degrees of freedom
#  Current data and model not fit yet.
# Response successfully loaded.
#
# Fit statistic  : Chi-Squared                   78.38     using 14 bins.
#
# Test statistic : Chi-Squared                   78.38     using 14 bins.
#  Null hypothesis probability of 8.39e-12 with 12 degrees of freedom
#  Current data and model not fit yet.
# Spectrum 1  Spectral Data File: uzsex_src_spectrum_bin25.ds
# Net count rate (cts/s) for Spectrum:1  1.977e-02 +/- 1.779e-03 (61.9 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-14
#   Telescope: XMM Instrument: EPIC  Channel Type: PI
#   Exposure Time: 1.109e+04 sec
#  Using fit statistic: chi
#  Using Background File                uzsex_bkg_spectrum_grp.ds
#   Background Exposure Time: 1.109e+04 sec
#  Using Response (RMF) File            uzsex_response_grp.rmf for Source 1
#
#  Spectral data counts: 354
#  Model predicted rate: 2.62893E-02
#
# ***Warning: Fit is not current.
#      2 channels (13-14) ignored in spectrum #     1
#      1 channels (1) ignored in spectrum #     1
#
# Fit statistic  : Chi-Squared                   63.42     using 11 bins.
#
# Test statistic : Chi-Squared                   63.42     using 11 bins.
#  Null hypothesis probability of 2.93e-10 with 9 degrees of freedom
#  Current data and model not fit yet.
#
# ***Warning: Fit is not current.
#
# Models will now use energy array created from:
#    0.1 - 2.4   1000 linear bins
#
#
# Fit statistic  : Chi-Squared                   63.42     using 11 bins.
#
# Test statistic : Chi-Squared                   63.42     using 11 bins.
#  Null hypothesis probability of 2.93e-10 with 9 degrees of freedom
#  Current data and model not fit yet.
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      1.00000      +/-  0.0
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9None
#     3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              2.308296e+11     using 11 bins.
#
# Test statistic : Chi-Squared              2.308296e+11     using 11 bins.
#  Null hypothesis probability of 0.000000e+00 with 6 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              3.132555e+12     using 11 bins.
#
# Test statistic : Chi-Squared              3.132555e+12     using 11 bins.
#  Null hypothesis probability of 0.000000e+00 with 6 degrees of freedom
#  Current data and model not fit yet.
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000E-04  +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            0.400000     frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      0.500000     +/-  0.0
#    7    3   apec       Abundanc            0.400000     frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              3.132555e+12     using 11 bins.
#
# Test statistic : Chi-Squared              3.132555e+12     using 11 bins.
#  Null hypothesis probability of 0.000000e+00 with 7 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared                   12.48     using 11 bins.
#
# Test statistic : Chi-Squared                   12.48     using 11 bins.
#  Null hypothesis probability of 8.58e-02 with 7 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          2:kT        5:norm          6:kT        9:norm
# 8.16944      3439.28      -3      0.878640   8.64478e-06      0.289829   5.97674e-06
# 6.21268      134776       -4      0.801576   9.88384e-06      0.173295   5.99784e-06
# 5.69112      132718       -5      0.796680   9.86432e-06      0.185103   6.88828e-06
# 5.68326      9091.19      -1      0.792541   9.95288e-06      0.176444   7.01660e-06
# ==================================================
#  Variances and Principal Axes
#                  2        5        6        9
#  8.8635E-13|  0.0000  -0.9567  -0.0000  -0.2912
#  4.8166E-12|  0.0000   0.2912  -0.0000  -0.9567
#  1.9935E-03| -0.7577  -0.0000   0.6526  -0.0000
#  1.3974E-02|  0.6526  -0.0000   0.7577  -0.0000
# --------------------------------------------------
#
# ================================================
#   Covariance Matrix
#         1           2           3           4
#    7.096e-03  -8.134e-08   5.924e-03  -5.629e-08
#   -8.134e-08   3.082e-12  -1.283e-07   8.099e-13
#    5.924e-03  -1.283e-07   8.872e-03  -1.288e-07
#   -5.629e-08   8.099e-13  -1.288e-07   6.636e-12
# ------------------------------------------------
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000E-04  frozen
#    2    2   apec       kT         keV      0.792541     +/-  8.42362E-02
#    3    2   apec       Abundanc            0.400000     frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                9.95288E-06  +/-  1.75551E-06
#    6    3   apec       kT         keV      0.176444     +/-  9.41908E-02
#    7    3   apec       Abundanc            0.400000     frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                7.01660E-06  +/-  2.57602E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    5.68     using 11 bins.
#
# Test statistic : Chi-Squared                    5.68     using 11 bins.
#  Null hypothesis probability of 5.77e-01 with 7 degrees of freedom
# Spectrum 1: Upper range bound          2.4 reset by matrix bound to          2.4
# Parameter distribution is derived from fit covariance matrix.
#  Model Flux 5.1215e-05 photons (2.918e-14 ergs/cm^2/s) range (0.10000 - 2.4000 keV)
#      Error range 3.409e-05 - 6.487e-05    (2.230e-14 - 3.139e-14)  (68.00% confidence)
# eguma
#
# 1 spectrum  in use
#
# Spectral Data File: eguma_src_spectrum_bin25.ds  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  6.834e-01 +/- 2.140e-02 (97.7 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-40
#   Telescope: XMM Instrument: EPIC  Channel Type: PI
#   Exposure Time: 1528 sec
#  Using fit statistic: chi
#  Using Background File                bkg_spectrum_grp.ds
#   Background Exposure Time: 1.002e+04 sec
#  Using Response (RMF) File            response_grp.rmf for Source 1
#
#
# Fit statistic  : Chi-Squared                  956.96     using 40 bins.
#
# Test statistic : Chi-Squared                  956.96     using 40 bins.
#  Null hypothesis probability of 1.66e-177 with 36 degrees of freedom
#  Current data and model not fit yet.
# Net count rate (cts/s) for Spectrum:1  6.793e-01 +/- 2.148e-02 (97.1 % total)
#
# Fit statistic  : Chi-Squared                  940.51     using 40 bins.
#
# Test statistic : Chi-Squared                  940.51     using 40 bins.
#  Null hypothesis probability of 4.63e-174 with 36 degrees of freedom
#  Current data and model not fit yet.
# Response successfully loaded.
#
# Fit statistic  : Chi-Squared                  933.72     using 40 bins.
#
# Test statistic : Chi-Squared                  933.72     using 40 bins.
#  Null hypothesis probability of 1.22e-172 with 36 degrees of freedom
#  Current data and model not fit yet.
# Spectrum 1  Spectral Data File: eguma_src_spectrum_bin25.ds
# Net count rate (cts/s) for Spectrum:1  6.793e-01 +/- 2.148e-02 (97.1 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-40
#   Telescope: XMM Instrument: EPIC  Channel Type: PI
#   Exposure Time: 1528 sec
#  Using fit statistic: chi
#  Using Background File                eguma_bkg_spectrum_grp.ds
#   Background Exposure Time: 1528 sec
#  Using Response (RMF) File            eguma_response_grp.rmf for Source 1
#
#  Spectral data counts: 1069
#  Model predicted rate: 2.41095E-02
#
# ***Warning: Fit is not current.
#      2 channels (39-40) ignored in spectrum #     1
#      1 channels (1) ignored in spectrum #     1
#
# Fit statistic  : Chi-Squared                  879.80     using 37 bins.
#
# Test statistic : Chi-Squared                  879.80     using 37 bins.
#  Null hypothesis probability of 1.68e-163 with 33 degrees of freedom
#  Current data and model not fit yet.
#
# ***Warning: Fit is not current.
#
# Models will now use energy array created from:
#    0.1 - 2.4   1000 linear bins
#
#
# Fit statistic  : Chi-Squared                  879.80     using 37 bins.
#
# Test statistic : Chi-Squared                  879.80     using 37 bins.
#  Null hypothesis probability of 1.68e-163 with 33 degrees of freedom
#  Current data and model not fit yet.
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      1.00000      +/-  0.0
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.853560e+09     using 37 bins.
#
# Test statistic : Chi-Squared              1.853560e+09     using 37 bins.
#  Null hypothesis probability of 0.000000e+00 with 32 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              1.987345e+10     using 37 bins.
#
# Test statistic : Chi-Squared              1.987345e+10     using 37 bins.
#  Null hypothesis probability of 0.000000e+00 with 32 degrees of freedom
#  Current data and model not fit yet.
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000E-04  +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            0.400000     frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      0.500000     +/-  0.0
#    7    3   apec       Abundanc            0.400000     frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.987345e+10     using 37 bins.
#
# Test statistic : Chi-Squared              1.987345e+10     using 37 bins.
#  Null hypothesis probability of 0.000000e+00 with 33 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared                  112.15     using 37 bins.
#
# Test statistic : Chi-Squared                  112.15     using 37 bins.
#  Null hypothesis probability of 1.5None
# 0e-10 with 33 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          2:kT        5:norm          6:kT        9:norm
# 96.8269      22642.4      -3       1.03485   0.000340275      0.133981   0.000191366
# 49.0642      57049        -4      0.979428   0.000323243      0.196800   0.000186379
# 32.7026      35992.5      -5       1.02211   0.000294074      0.256950   0.000241797
# 28.4465      13692.1      -6       1.07133   0.000282949      0.263522   0.000282705
# 28.0963      1623.12      -7       1.09040   0.000287951      0.265516   0.000282346
# 27.9035      304.942      -8       1.10599   0.000290956      0.267861   0.000283553
# 27.8874      213.761      -9       1.11175   0.000292439      0.268518   0.000283641
# 27.8874      10.0172     -10       1.11172   0.000292439      0.268518   0.000283641
# ==================================================
#  Variances and Principal Axes
#                  2        5        6        9
#  1.8083E-10| -0.0002   0.7874   0.0004   0.6164
#  6.9972E-10|  0.0001  -0.6164  -0.0004   0.7874
#  1.8381E-04|  0.1729   0.0006  -0.9849  -0.0001
#  2.1964E-03|  0.9849   0.0002   0.1729   0.0001
# --------------------------------------------------
#
# ================================================
#   Covariance Matrix
#         1           2           3           4
#    2.136e-03   3.519e-07   3.427e-04   2.141e-07
#    3.519e-07   4.905e-10  -4.507e-08  -2.263e-10
#    3.427e-04  -4.507e-08   2.440e-04   5.249e-08
#    2.141e-07  -2.263e-10   5.249e-08   5.258e-10
# ------------------------------------------------
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000E-04  frozen
#    2    2   apec       kT         keV      1.11172      +/-  4.62199E-02
#    3    2   apec       Abundanc            0.400000     frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                2.92439E-04  +/-  2.21477E-05
#    6    3   apec       kT         keV      0.268518     +/-  1.56196E-02
#    7    3   apec       Abundanc            0.400000     frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                2.83641E-04  +/-  2.29295E-05
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   27.89     using 37 bins.
#
# Test statistic : Chi-Squared                   27.89     using 37 bins.
#  Null hypothesis probability of 7.20e-01 with 33 degrees of freedom
# Spectrum 1: Upper range bound          2.4 reset by matrix bound to          2.4
# Parameter distribution is derived from fit covariance matrix.
#  Model Flux 0.0013014 photons (8.3464e-13 ergs/cm^2/s) range (0.10000 - 2.4000 keV)
#      Error range  0.001243 - 0.001352    (8.032e-13 - 8.661e-13)  (68.00% confidence)
# eggr38
#
# 1 spectrum  in use
#
# Spectral Data File: eggr38_src_spectrum_bin25.ds  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  1.596e-01 +/- 3.081e-03 (89.6 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-114
#   Telescope: XMM Instrument: EPIC  Channel Type: PI
#   Exposure Time: 1.975e+04 sec
#  Using fit statistic: chi
#  Using Background File                bkg_spectrum_grp.ds
#   Background Exposure Time: 1.002e+04 sec
#  Using Response (RMF) File            response_grp.rmf for Source 1
#
#
# Fit statistic  : Chi-Squared                80437.29     using 114 bins.
#
# Test statistic : Chi-Squared                80437.29     using 114 bins.
#  Null hypothesis probability of 0.00e+00 with 110 degrees of freedom
#  Current data and model not fit yet.
# Net count rate (cts/s) for Spectrum:1  1.608e-01 +/- 3.042e-03 (90.3 % total)
#
# Fit statistic  : Chi-Squared                82413.13     using 114 bins.
#
# Test statistic : Chi-Squared                82413.13     using 114 bins.
#  Null hypothesis probability of 0.00e+00 with 110 degrees of freedom
#  Current data and model not fit yet.
# Response successfully loaded.
#
# Fit statistic  : Chi-Squared                73080.43     using 114 bins.
#
# Test statistic : Chi-Squared                73080.43     using 114 bins.
#  Null hypothesis probability of 0.00e+00 with 110 degrees of freedom
#  Current data and model not fit yet.
# Spectrum 1  Spectral Data File: eggr38_src_spectrum_bin25.ds
# Net count rate (cts/s) for Spectrum:1  1.608e-01 +/- 3.042e-03 (90.3 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-114
#   Telescope: XMM Instrument: EPIC  Channel Type: PI
#   Exposure Time: 1.975e+04 sec
#  Using fit statistic: chi
#  Using Background File                eggr38_bkg_spectrum_grp.ds
#   Background Exposure Time: 1.975e+04 sec
#  Using Response (RMF) File            eggr38_response_grp.rmf for Source 1
#
#  Spectral data counts: 3516
#  Model predicted rate: 0.623962
#
# ***Warning: Fit is not current.
#      7 channels (108-114) ignored in spectrum #     1
#      1 channels (1) ignored in spectrum #     1
#
# Fit statistic  : Chi-Squared                19300.00     using 106 bins.
#
# Test statistic : Chi-Squared                19300.00     using 106 bins.
#  Null hypothesis probability of 0.00e+00 with 102 degrees of freedom
#  Current data and model not fit yet.
#
# ***Warning: Fit is not current.
#
# Models will now use energy array created from:
#    0.1 - 2.4   1000 linear bins
#
#
# Fit statistic  : Chi-Squared                19300.00     using 106 bins.
#
# Test statistic : Chi-Squared                19300.00     using 106 bins.
#  Null hypothesis probability of 0.00e+00 with 102 degrees of freedom
#  Current data and model not fit yet.
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      1.00000      +/-  0.0
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       RedshifNone
# t            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              9.088424e+10     using 106 bins.
#
# Test statistic : Chi-Squared              9.088424e+10     using 106 bins.
#  Null hypothesis probability of 0.000000e+00 with 101 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              8.016567e+11     using 106 bins.
#
# Test statistic : Chi-Squared              8.016567e+11     using 106 bins.
#  Null hypothesis probability of 0.000000e+00 with 101 degrees of freedom
#  Current data and model not fit yet.
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000E-04  +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            0.400000     frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      0.500000     +/-  0.0
#    7    3   apec       Abundanc            0.400000     frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              8.016567e+11     using 106 bins.
#
# Test statistic : Chi-Squared              8.016567e+11     using 106 bins.
#  Null hypothesis probability of 0.000000e+00 with 102 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared                  384.31     using 106 bins.
#
# Test statistic : Chi-Squared                  384.31     using 106 bins.
#  Null hypothesis probability of 2.38e-34 with 102 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          2:kT        5:norm          6:kT        9:norm
# 197.782      134172       -1       1.06285   7.50833e-05      0.235639   6.15935e-05
# 130.902      737835       -2       1.08599   7.30801e-05      0.280288   8.38696e-05
# 127.611      71457.7      -3       1.11002   7.23822e-05      0.276040   8.67478e-05
# 127.359      6688.31      -4       1.12384   7.32406e-05      0.277433   8.67756e-05
# 127.359      565.362      -5       1.12368   7.32409e-05      0.277433   8.67756e-05
# ==================================================
#  Variances and Principal Axes
#                  2        5        6        9
#  4.4837E-12| -0.0001   0.8069   0.0001   0.5907
#  1.7768E-11|  0.0000  -0.5907  -0.0001   0.8069
#  5.7905E-05|  0.1555   0.0002  -0.9878   0.0000
#  8.0147E-04|  0.9878   0.0000   0.1555   0.0000
# --------------------------------------------------
#
# ================================================
#   Covariance Matrix
#         1           2           3           4
#    7.835e-04   2.599e-08   1.142e-04   2.409e-08
#    2.599e-08   1.131e-11  -5.070e-09  -5.527e-12
#    1.142e-04  -5.070e-09   7.588e-05   3.473e-09
#    2.409e-08  -5.527e-12   3.473e-09   1.387e-11
# ------------------------------------------------
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000E-04  frozen
#    2    2   apec       kT         keV      1.12368      +/-  2.79910E-02
#    3    2   apec       Abundanc            0.400000     frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                7.32409E-05  +/-  3.36240E-06
#    6    3   apec       kT         keV      0.277433     +/-  8.71075E-03
#    7    3   apec       Abundanc            0.400000     frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                8.67756E-05  +/-  3.72474E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  127.36     using 106 bins.
#
# Test statistic : Chi-Squared                  127.36     using 106 bins.
#  Null hypothesis probability of 4.53e-02 with 102 degrees of freedom
# Spectrum 1: Upper range bound          2.4 reset by matrix bound to          2.4
# Parameter distribution is derived from fit covariance matrix.
#  Model Flux 0.00035844 photons (2.2937e-13 ergs/cm^2/s) range (0.10000 - 2.4000 keV)
#      Error range 0.0003514 - 0.0003665    (2.249e-13 - 2.329e-13)  (68.00% confidence)
# wd1436-216
#
# 1 spectrum  in use
#
# Spectral Data File: wd1436-216_src_spectrum_bin25.ds  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  1.765e-02 +/- 1.910e-03 (49.1 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-16
#   Telescope: XMM Instrument: EPIC  Channel Type: PI
#   Exposure Time: 1.136e+04 sec
#  Using fit statistic: chi
#  Using Background File                bkg_spectrum_grp.ds
#   Background Exposure Time: 1.002e+04 sec
#  Using Response (RMF) File            response_grp.rmf for Source 1
#
#
# Fit statistic  : Chi-Squared                11696.60     using 16 bins.
#
# Test statistic : Chi-Squared                11696.60     using 16 bins.
#  Null hypothesis probability of 0.00e+00 with 12 degrees of freedom
#  Current data and model not fit yet.
# Net count rate (cts/s) for Spectrum:1  1.992e-02 +/- 1.780e-03 (55.5 % total)
#
# Fit statistic  : Chi-Squared                13649.66     using 16 bins.
#
# Test statistic : Chi-Squared                13649.66     using 16 bins.
#  Null hypothesis probability of 0.00e+00 with 12 degrees of freedom
#  Current data and model not fit yet.
# Response successfully loaded.
#
# Fit statistic  : Chi-Squared                13292.98     using 16 bins.
#
# Test statistic : Chi-Squared                13292.98     using 16 bins.
#  Null hypothesis probability of 0.00e+00 with 12 degrees of freedom
#  Current data and model not fit yet.
# Spectrum 1  Spectral Data File: wd1436-216_src_spectrum_bin25.ds
# Net count rate (cts/s) for Spectrum:1  1.992e-02 +/- 1.780e-03 (55.5 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-16
#   Telescope: XMM Instrument: EPIC  Channel Type: PI
#   Exposure Time: 1.136e+04 sec
#  Using fit statistic: chi
#  Using Background File                wd1436-216_bkg_spectrum_grp.ds
#   Background Exposure Time: 1.133e+04 sec
#  Using Response (RMF) File            wd1436-216_response_grp.rmf for Source 1
#
#  Spectral data counts: 408
#  Model predicted rate: 0.177761
#
# ***Warning: Fit is not current.
#      3 channels (14-16) ignored in spectrum #     1
#      1 channels (1) ignored in spectrum #     1
#
# Fit statistic  : Chi-Squared                 8118.31     using 12 bins.
#
# Test statistic : Chi-Squared                 8118.31     using 12 bins.
#  Null hypothesis probability of 0.00e+00 with 8 degrees of freedom
#  Current data and model not fit yet.
#
# ***Warning: Fit is not current.
#
# Models will now use energy array created from:
#    0.1 - 2.4   1000 linear bins
#
#
# Fit statistic  : Chi-Squared                 8118.31     using 12 bins.
#
# Test statistic : Chi-Squared                 8118.31     using 12 bins.
#  Null hypothesis probability of 0.00e+00 with 8 degrees of freedom
#  Current data and model not fit yet.
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      1.00000      +/-  0.0
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              2.152532e+11     using 12 bins.
#
# Test statistic : Chi-Squared              2.152532e+11     using 12 bins.
#  Null hypothesis probability of 0.000000e+00 with 7 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              3.348136e+12     using 12 bins.
#
# Test statistic : Chi-Squared              3.348136e+12     using 12 bins.
#  Null hypothesis probability of 0.000000e+00 with 7 degrees of freedom
#  Current data and model not fit yet.
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000E-04  +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0      None
#
#    3    2   apec       Abundanc            0.400000     frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      0.500000     +/-  0.0
#    7    3   apec       Abundanc            0.400000     frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              3.348136e+12     using 12 bins.
#
# Test statistic : Chi-Squared              3.348136e+12     using 12 bins.
#  Null hypothesis probability of 0.000000e+00 with 8 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared                   37.52     using 12 bins.
#
# Test statistic : Chi-Squared                   37.52     using 12 bins.
#  Null hypothesis probability of 9.22e-06 with 8 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          2:kT        5:norm          6:kT        9:norm
# 18.6561      125990       -3       1.14444   1.09246e-05      0.234272   6.99903e-06
# 14.1487      236819       -4       1.22053   1.00045e-05      0.248607   1.09690e-05
# 13.1689      35818.6      -5       1.32106   1.11081e-05      0.246859   1.07045e-05
# 12.2777      10180.7      -6       1.45245   1.26702e-05      0.251774   1.02820e-05
# 11.0627      7301.58      -7       1.65520   1.48013e-05      0.257046   9.66392e-06
# 9.8173       11409.6      -8       1.99664   1.73144e-05      0.259803   8.87841e-06
# 9.24609      21426.2      -9       2.37783   1.84538e-05      0.259328   8.59441e-06
# 9.03834      17710.5     -10       2.74388   1.86634e-05      0.258753   8.63132e-06
# 8.9922       5607.37     -11       3.01869   1.87434e-05      0.258506   8.69170e-06
# 8.98803      926.901     -12       3.10575   1.87734e-05      0.258519   8.70766e-06
# ==================================================
#  Variances and Principal Axes
#                  2        5        6        9
#  2.1330E-12| -0.0000   0.4967   0.0000   0.8679
#  1.1188E-11| -0.0000   0.8679   0.0000  -0.4967
#  1.2495E-03|  0.0005   0.0000  -1.0000   0.0000
#  2.8447E+00|  1.0000   0.0000   0.0005   0.0000
# --------------------------------------------------
#
# ================================================
#   Covariance Matrix
#         1           2           3           4
#    2.845e+00   1.650e-06   1.447e-03   3.754e-07
#    1.650e-06   1.030e-11  -2.118e-08  -3.469e-12
#    1.447e-03  -2.118e-08   1.250e-03  -1.211e-08
#    3.754e-07  -3.469e-12  -1.211e-08   4.538e-12
# ------------------------------------------------
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000E-04  frozen
#    2    2   apec       kT         keV      3.10575      +/-  1.68663
#    3    2   apec       Abundanc            0.400000     frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.87734E-05  +/-  3.20928E-06
#    6    3   apec       kT         keV      0.258519     +/-  3.53585E-02
#    7    3   apec       Abundanc            0.400000     frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                8.70766E-06  +/-  2.13023E-06
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    8.99     using 12 bins.
#
# Test statistic : Chi-Squared                    8.99     using 12 bins.
#  Null hypothesis probability of 3.43e-01 with 8 degrees of freedom
# Spectrum 1: Upper range bound          2.4 reset by matrix bound to          2.4
# Parameter distribution is derived from fit covariance matrix.
#  Model Flux 4.3391e-05 photons (3.0649e-14 ergs/cm^2/s) range (0.10000 - 2.4000 keV)
#      Error range 3.751e-05 - 5.233e-05    (2.772e-14 - 3.507e-14)  (68.00% confidence)
# wd1458+171
#
# 1 spectrum  in use
#
# Spectral Data File: wd1458+171_src_spectrum_bin10.ds  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  3.709e-03 +/- 1.658e-03 (16.4 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-22
#   Telescope: XMM Instrument: EPIC  Channel Type: PI
#   Exposure Time: 1.002e+04 sec
#  Using fit statistic: chi
#  Using Background File                bkg_spectrum_grp.ds
#   Background Exposure Time: 1.002e+04 sec
#  Using Response (RMF) File            response_grp.rmf for Source 1
#
#
# Fit statistic  : Chi-Squared                  333.18     using 22 bins.
#
# Test statistic : Chi-Squared                  333.18     using 22 bins.
#  Null hypothesis probability of 6.91e-60 with 18 degrees of freedom
#  Current data and model not fit yet.
# Net count rate (cts/s) for Spectrum:1  3.709e-03 +/- 1.658e-03 (16.4 % total)
#
# Fit statistic  : Chi-Squared                  333.18     using 22 bins.
#
# Test statistic : Chi-Squared                  333.18     using 22 bins.
#  Null hypothesis probability of 6.91e-60 with 18 degrees of freedom
#  Current data and model not fit yet.
# Response successfully loaded.
#
# Fit statistic  : Chi-Squared                  325.84     using 22 bins.
#
# Test statistic : Chi-Squared                  325.84     using 22 bins.
#  Null hypothesis probability of 2.28e-58 with 18 degrees of freedom
#  Current data and model not fit yet.
# Spectrum 1  Spectral Data File: wd1458+171_src_spectrum_bin10.ds
# Net count rate (cts/s) for Spectrum:1  3.709e-03 +/- 1.658e-03 (16.4 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-22
#   Telescope: XMM Instrument: EPIC  Channel Type: PI
#   Exposure Time: 1.002e+04 sec
#  Using fit statistic: chi
#  Using Background File                wd1458+171_bkg_spectrum_grp.ds
#   Background Exposure Time: 1.002e+04 sec
#  Using Response (RMF) File            wd1458+171_response_grp.rmf for Source 1
#
#  Spectral data counts: 226
#  Model predicted rate: 2.31461E-02
#
# ***Warning: Fit is not current.
#      6 channels (17-22) ignored in spectrum #     1
#      1 channels (1) ignored in spectrum #     1
#
# Fit statistic  : Chi-Squared                  180.44     using 15 bins.
#
# Test statistic : Chi-Squared                  180.44     using 15 bins.
#  Null hypothesis probability of 8.30e-33 with 11 degrees of freedom
#  Current data and model not fit yet.
#
# ***Warning: Fit is not current.
#
# Models will now use energy array created from:
# None
#    0.1 - 2.4   1000 linear bins
#
#
# Fit statistic  : Chi-Squared                  180.44     using 15 bins.
#
# Test statistic : Chi-Squared                  180.44     using 15 bins.
#  Null hypothesis probability of 8.30e-33 with 11 degrees of freedom
#  Current data and model not fit yet.
#
# ========================================================================
# Model apec<1>*phabs<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   apec       kT         keV      1.00000      +/-  0.0
#    2    1   apec       Abundanc            1.00000      frozen
#    3    1   apec       Redshift            0.0          frozen
#    4    1   apec       norm                1.00000      +/-  0.0
#    5    2   phabs      nH         10^22    1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              7.238498e+10     using 15 bins.
#
# Test statistic : Chi-Squared              7.238498e+10     using 15 bins.
#  Null hypothesis probability of 0.000000e+00 with 12 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              1.300546e+12     using 15 bins.
#
# Test statistic : Chi-Squared              1.300546e+12     using 15 bins.
#  Null hypothesis probability of 0.000000e+00 with 12 degrees of freedom
#  Current data and model not fit yet.
#
# ========================================================================
# Model apec<1>*phabs<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   apec       kT         keV      1.00000      +/-  0.0
#    2    1   apec       Abundanc            0.400000     frozen
#    3    1   apec       Redshift            0.0          frozen
#    4    1   apec       norm                1.00000      +/-  0.0
#    5    2   phabs      nH         10^22    1.00000E-04  +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.300546e+12     using 15 bins.
#
# Test statistic : Chi-Squared              1.300546e+12     using 15 bins.
#  Null hypothesis probability of 0.000000e+00 with 13 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared                   21.50     using 15 bins.
#
# Test statistic : Chi-Squared                   21.50     using 15 bins.
#  Null hypothesis probability of 6.35e-02 with 13 degrees of freedom
#  Current data and model not fit yet.
#  renorm: no renormalization necessary
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:kT        4:norm
# 19.2872      4.99404      -3       1.37915   4.29806e-06
# 18.723       232030        0       1.26859   4.55489e-06
# 18.7033      35430.8      -1       1.30682   4.85273e-06
# 18.6898      7767.2        0       1.29293   4.83066e-06
# 18.6881      5805.43      -1       1.28810   4.78919e-06
# ==============================
#  Variances and Principal Axes
#                  1        4
#  1.6746E-12| -0.0000   1.0000
#  8.2411E-02|  1.0000   0.0000
# ------------------------------
#
# ========================
#   Covariance Matrix
#         1           2
#    8.241e-02   4.459e-07
#    4.459e-07   4.087e-12
# ------------------------
#
# ========================================================================
# Model apec<1>*phabs<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   apec       kT         keV      1.28810      +/-  0.287072
#    2    1   apec       Abundanc            0.400000     frozen
#    3    1   apec       Redshift            0.0          frozen
#    4    1   apec       norm                4.78919E-06  +/-  2.02158E-06
#    5    2   phabs      nH         10^22    1.00000E-04  frozen
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   18.69     using 15 bins.
#
# Test statistic : Chi-Squared                   18.69     using 15 bins.
#  Null hypothesis probability of 1.33e-01 with 13 degrees of freedom
# Spectrum 1: Upper range bound          2.4 reset by matrix bound to          2.4
# Parameter distribution is derived from fit covariance matrix.
#  Model Flux 8.5082e-06 photons (6.3289e-15 ergs/cm^2/s) range (0.10000 - 2.4000 keV)
#      Error range 5.693e-06 - 1.014e-05    (4.308e-15 - 7.771e-15)  (68.00% confidence)
# wd1504+546
#
# 1 spectrum  in use
#
# Spectral Data File: wd1504+546_src_spectrum_bin10.ds  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  2.992e-02 +/- 4.310e-03 (61.7 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-13
#   Telescope: XMM Instrument: EPIC  Channel Type: PI
#   Exposure Time: 2681 sec
#  Using fit statistic: chi
#  Using Background File                bkg_spectrum_grp.ds
#   Background Exposure Time: 1.002e+04 sec
#  Using Response (RMF) File            response_grp.rmf for Source 1
#
#
# Fit statistic  : Chi-Squared                   42.54     using 13 bins.
#
# Test statistic : Chi-Squared                   42.54     using 13 bins.
#  Null hypothesis probability of 1.31e-05 with 11 degrees of freedom
#  Current data and model not fit yet.
# Net count rate (cts/s) for Spectrum:1  7.615e-03 +/- 4.710e-03 (15.7 % total)
#
# Fit statistic  : Chi-Squared                   14.97     using 13 bins.
#
# Test statistic : Chi-Squared                   14.97     using 13 bins.
#  Null hypothesis probability of 1.84e-01 with 11 degrees of freedom
#  Current data and model not fit yet.
# Response successfully loaded.
#
# Fit statistic  : Chi-Squared                   17.55     using 13 bins.
#
# Test statistic : Chi-Squared                   17.55     using 13 bins.
#  Null hypothesis probability of 9.26e-02 with 11 degrees of freedom
#  Current data and model not fit yet.
# Spectrum 1  Spectral Data File: wd1504+546_src_spectrum_bin10.ds
# Net count rate (cts/s) for Spectrum:1  7.615e-03 +/- 4.710e-03 (15.7 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-13
#   Telescope: XMM Instrument: EPIC  Channel Type: PI
#   Exposure Time: 2681 sec
#  Using fit statistic: chi
#  Using Background File                wd1504+546_bkg_spectrum_grp.ds
#   Background Exposure Time: 2681 sec
#  Using Response (RMF) File            wd1504+546_response_grp.rmf for Source 1
#
#  Spectral data counts: 130
#  Model predicted rate: 3.18363E-03
#
# ***Warning: Fit is not current.
#      5 channels (9-13) ignored in spectrum #     1
#      1 channels (1) ignored in spectrum #     1
#
# Fit statistic  : Chi-Squared                    8.26     using 7 bins.
#
# Test statistic : Chi-Squared                    8.26     using 7 bins.
#  Null hypothesis probability of 1.42e-01 with 5 degrees of freedom
#  Current data and model not fit yet.
#
# ***Warning: Fit is not current.
#
# Models will now use energy array created from:
#    0.1 - 2.4   1000 linear bins
#
#
# Fit statistic  : Chi-Squared                    8.26     using 7 bins.
#
# Test statistic : Chi-Squared                    8.26     using 7 bins.
#  Null hypothesis probability of 1.42e-01 with 5 degrees of freedom
#  Current data and model not fit yet.
#
# ========================================================================
# Model apec<1>*phabs<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   apec       kT         keV      1.00000      +/-  0.0
#    2    1   apec       Abundanc            1.00000      frozen
#    3    1   apec       Redshift            0.0          frozen
#    4    1   apec       norm                1.00000      +/-  0.0
#    5    2   phabs      nH         10^22    1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              4.835493e+09     using 7 bins.
#
# Test statistic : Chi-Squared              4.835493e+09     using 7 biNone
# ns.
#  Null hypothesis probability of 0.000000e+00 with 4 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              9.738096e+10     using 7 bins.
#
# Test statistic : Chi-Squared              9.738096e+10     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 4 degrees of freedom
#  Current data and model not fit yet.
#
# ========================================================================
# Model apec<1>*phabs<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   apec       kT         keV      1.00000      +/-  0.0
#    2    1   apec       Abundanc            0.400000     frozen
#    3    1   apec       Redshift            0.0          frozen
#    4    1   apec       norm                1.00000      +/-  0.0
#    5    2   phabs      nH         10^22    1.00000E-04  +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              9.738096e+10     using 7 bins.
#
# Test statistic : Chi-Squared              9.738096e+10     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 5 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared                    5.50     using 7 bins.
#
# Test statistic : Chi-Squared                    5.50     using 7 bins.
#  Null hypothesis probability of 3.58e-01 with 5 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:kT        4:norm
# 4.83372      0.473567     -3      0.825809   6.60343e-06
# 3.25207      79398.3       0      0.548326   6.87702e-06
# 2.27138      163189       -1      0.342728   1.11162e-05
# 1.4417       98933.2      -2      0.359712   1.47223e-05
# 1.44023      2928.28      -3      0.356174   1.47433e-05
# ==============================
#  Variances and Principal Axes
#                  1        4
#  1.9160E-11|  0.0000   1.0000
#  1.5502E-02|  1.0000  -0.0000
# ------------------------------
#
# ========================
#   Covariance Matrix
#         1           2
#    1.550e-02  -5.840e-07
#   -5.840e-07   4.116e-11
# ------------------------
#
# ========================================================================
# Model apec<1>*phabs<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   apec       kT         keV      0.356174     +/-  0.124509
#    2    1   apec       Abundanc            0.400000     frozen
#    3    1   apec       Redshift            0.0          frozen
#    4    1   apec       norm                1.47433E-05  +/-  6.41542E-06
#    5    2   phabs      nH         10^22    1.00000E-04  frozen
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    1.44     using 7 bins.
#
# Test statistic : Chi-Squared                    1.44     using 7 bins.
#  Null hypothesis probability of 9.20e-01 with 5 degrees of freedom
# Spectrum 1: Upper range bound          2.4 reset by matrix bound to          2.4
# Parameter distribution is derived from fit covariance matrix.
#  Model Flux 3.3226e-05 photons (2.1448e-14 ergs/cm^2/s) range (0.10000 - 2.4000 keV)
#      Error range 2.011e-05 - 6.059e-05    (1.307e-14 - 3.011e-14)  (68.00% confidence)
# v727car
#
# 1 spectrum  in use
#
# Spectral Data File: v727car_src_spectrum_bin10.ds  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  2.597e-02 +/- 2.786e-03 (58.4 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-26
#   Telescope: XMM Instrument: EPIC  Channel Type: PI
#   Exposure Time: 6116 sec
#  Using fit statistic: chi
#  Using Background File                bkg_spectrum_grp.ds
#   Background Exposure Time: 1.002e+04 sec
#  Using Response (RMF) File            response_grp.rmf for Source 1
#
#
# Fit statistic  : Chi-Squared                   50.47     using 26 bins.
#
# Test statistic : Chi-Squared                   50.47     using 26 bins.
#  Null hypothesis probability of 1.23e-03 with 24 degrees of freedom
#  Current data and model not fit yet.
# Net count rate (cts/s) for Spectrum:1  3.076e-02 +/- 2.698e-03 (69.2 % total)
#
# Fit statistic  : Chi-Squared                   65.99     using 26 bins.
#
# Test statistic : Chi-Squared                   65.99     using 26 bins.
#  Null hypothesis probability of 8.71e-06 with 24 degrees of freedom
#  Current data and model not fit yet.
# Response successfully loaded.
#
# Fit statistic  : Chi-Squared                   60.38     using 26 bins.
#
# Test statistic : Chi-Squared                   60.38     using 26 bins.
#  Null hypothesis probability of 5.65e-05 with 24 degrees of freedom
#  Current data and model not fit yet.
# Spectrum 1  Spectral Data File: v727car_src_spectrum_bin10.ds
# Net count rate (cts/s) for Spectrum:1  3.076e-02 +/- 2.698e-03 (69.2 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-26
#   Telescope: XMM Instrument: EPIC  Channel Type: PI
#   Exposure Time: 6116 sec
#  Using fit statistic: chi
#  Using Background File                v727car_bkg_spectrum_grp.ds
#   Background Exposure Time: 6102 sec
#  Using Response (RMF) File            v727car_response_grp.rmf for Source 1
#
#  Spectral data counts: 272
#  Model predicted rate: 1.55984E-02
#
# ***Warning: Fit is not current.
#      5 channels (22-26) ignored in spectrum #     1
#      1 channels (1) ignored in spectrum #     1
#
# Fit statistic  : Chi-Squared                   45.00     using 20 bins.
#
# Test statistic : Chi-Squared                   45.00     using 20 bins.
#  Null hypothesis probability of 4.15e-04 with 18 degrees of freedom
#  Current data and model not fit yet.
#
# ***Warning: Fit is not current.
#
# Models will now use energy array created from:
#    0.1 - 2.4   1000 linear bins
#
#
# Fit statistic  : Chi-Squared                   45.00     using 20 bins.
#
# Test statistic : Chi-Squared                   45.00     using 20 bins.
#  Null hypothesis probability of 4.15e-04 with 18 degrees of freedom
#  Current data and model not fit yet.
#
# ========================================================================
# Model apec<1>*phabs<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   apec       kT         keV      1.00000      +/-  0.0
#    2    1   apec       Abundanc            1.00000      frozen
#    3    1   apec       Redshift            0.0          frozen
#    4    1   apec       norm                1.00000      +/-  0.0
#    5    2   phabs      nH         10^22    1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              2.679226e+10     using 20 bins.
#
# Test statistic : Chi-Squared              2.679226e+10     using 20 bins.
#  Null hypothesis probability of 0.000000e+00 with 17 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              3.589905e+11     using 20 bins.
#
# Test statistic : Chi-Squared              3.589905e+11     using 20 bins.
#  Null hypothesis probability of 0.000000e+00 with 17 degrees of freedom
#  Current data and model not fit yet.
#
# ========================================================================
# Model apec<1>*phabs<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   apec       kT         keV      1.00000      +/-  0.0
#    2    1   apec       Abundanc            0.400000     frozen
#    3    1   apec       Redshift            0.0          frozen
#    4    1   apec       norm                1.00000      +/-  0.0
#    5    2   phabs      nH         10^22    1.00000E-04  +/-  0.0
# ________________________________________________________None
# ________________
#
#
# Fit statistic  : Chi-Squared              3.589905e+11     using 20 bins.
#
# Test statistic : Chi-Squared              3.589905e+11     using 20 bins.
#  Null hypothesis probability of 0.000000e+00 with 18 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared                   60.38     using 20 bins.
#
# Test statistic : Chi-Squared                   60.38     using 20 bins.
#  Null hypothesis probability of 1.78e-06 with 18 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:kT        4:norm
# 41.0141      22.0473      -3      0.764514   1.28249e-05
# 30.6415      663138       -4      0.618315   1.60993e-05
# 30.332       170461       -5      0.611354   1.70062e-05
# 30.3089      415.172      -6      0.606269   1.70452e-05
# 30.2853      1634.48      -7      0.599591   1.71120e-05
# 30.2826      1184.92      -8      0.596403   1.71478e-05
# ==============================
#  Variances and Principal Axes
#                  1        4
#  2.5881E-12|  0.0000   1.0000
#  3.6844E-03|  1.0000  -0.0000
# ------------------------------
#
# ========================
#   Covariance Matrix
#         1           2
#    3.684e-03  -3.423e-08
#   -3.423e-08   2.906e-12
# ------------------------
#
# ========================================================================
# Model apec<1>*phabs<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   apec       kT         keV      0.596403     +/-  6.06996E-02
#    2    1   apec       Abundanc            0.400000     frozen
#    3    1   apec       Redshift            0.0          frozen
#    4    1   apec       norm                1.71478E-05  +/-  1.70474E-06
#    5    2   phabs      nH         10^22    1.00000E-04  frozen
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   30.28     using 20 bins.
#
# Test statistic : Chi-Squared                   30.28     using 20 bins.
#  Null hypothesis probability of 3.48e-02 with 18 degrees of freedom
# Spectrum 1: Upper range bound          2.4 reset by matrix bound to          2.4
# Parameter distribution is derived from fit covariance matrix.
#  Model Flux 4.4444e-05 photons (3.1741e-14 ergs/cm^2/s) range (0.10000 - 2.4000 keV)
#      Error range 4.098e-05 - 4.859e-05    (2.908e-14 - 3.449e-14)  (68.00% confidence)

# %%
# plt.errorbar(np.arange(len(fluxes)), fluxes, yerr=[fluxes_el, fluxes_eu], marker='o', ls='none')
print(np.array(fluxes)/np.array(fluxes_el))
# Out:
# [ 4.24186338 26.51167339 51.53729278 10.47855397  3.13186557  2.5611152
#  11.91410571]

# %%
stars
# Out:
# ['uzsex',
#  'eguma',
#  'eggr38',
#  'wd1436-216',
#  'wd1458+171',
#  'wd1504+546',
#  'v727car']

# %%
lstars = [-2.51, -2.51, -2.51, -1.62, -2.51, -1.93, -3.11] #estimating from spectral type
prot = [0.596, 0.668,0.563,2.018,0.246,0.931,0.337] #from pceb_bob
dstar = [39.90,28.71,42.99,176.38,220.93,189.98, 29.22] #from odette

# %%
path = '/media/david/2tb_ext_hd/hddata/carmenes_binary/xraycat/'
xraycat = fits.open('{}J_ApJ_743_48_catalog.dat.fits'.format(path))
xraydata = xraycat[1].data

# %%
plt.figure(figsize=(8,6))
# -12.1730
# print(np.log10(fluxes))

lxs = []
lxes = []

for i, star in enumerate(stars):
    fx, fxel, fxeu = fluxes[i]*u.erg/u.cm**2/u.s, fluxes_el[i]*u.erg/u.cm**2/u.s, fluxes_eu[i]*u.erg/u.cm**2/u.s  
    d = dstar[i]*u.pc
    p = prot[i]*u.d
    lstar = (10**lstars[i])*u.Lsun
    lx = (4*np.pi)*(fx*(d.to(u.cm))**2).to(u.Lsun) #0.797 conversion factor from Wright+11
    lxs.append(lx)
    lxes.append(np.array(lx*[fxel/fx, fxeu/fx]))
    lx_star = lx/lstar
    # print(lx_star)
    print(star, lx.to(u.erg/u.s).value, (lx*(fxel/fx)).to(u.erg/u.s).value, (lx*(fxeu/fx)).to(u.erg/u.s).value)
    lx_star_err =  np.array(lx_star*[fxel/fx, fxeu/fx])
    # print(lx_star_err)
    if star == 'eguma':
        plt.errorbar(p, lx_star, yerr= [[lx_star_err[0]],[lx_star_err[1]]], marker='o', c='C4', markeredgecolor='k', label='EG\,UMa')
    else:
        plt.errorbar(p, lx_star, yerr= [[lx_star_err[0]],[lx_star_err[1]]], marker='o', c='C1', markeredgecolor='k', label='PCEBs')
#     if star == 'eguma':
#         fx = (10**-12.1730)*u.erg/u.cm**2/u.s
#         lx = (fx*(d.to(u.cm))**2).to(u.Lsun)
#         lx_star = lx/lstar
#         plt.errorbar(p, lx_star, yerr= [[lx_star_err[0]],[lx_star_err[1]]], marker='o', c='C2', markeredgecolor='k')
        
    
plt.scatter(xraydata['Prot'], 10**xraydata['Lx/bol'], marker='o', alpha=0.3, label='Wright et al. 2011')
plt.xscale('log')
plt.yscale('log')
handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys(), frameon=True)

# plt.legend()
plt.xlabel('Porb (d)')
plt.ylabel('L$_{\mathrm{x}}$/L$_{\mathrm{bol}}$')
plt.tight_layout()
plt.savefig('../plots/eg_uma_Lx_prot.png', facecolor='w')
plt.savefig('../plots/eg_uma_Lx_prot.pdf', facecolor='w')
# Out:
# uzsex 5.558375393735309e+27 1.310361720897834e+27 4.2062005049587523e+26
# eguma 8.231424664278682e+28 3.104830292140709e+27 3.1035687561792145e+27
# eggr38 5.072118652561195e+28 9.841647434689051e+26 7.79685388188791e+26
# wd1436-216 1.1408557760136772e+29 1.0887530659080812e+28 1.6436753445845393e+28
# wd1458+171 3.696123627803257e+28 1.1801667560958785e+28 8.423357073019123e+27
# wd1504+546 9.262050334975735e+28 3.6164130113192216e+28 3.740864819320811e+28
# v727car 3.242558676342352e+27 2.7216131492421285e+26 2.8036754005375138e+26

# %%
plt.figure(figsize=(16,6))
# -12.1730


plt.subplot(121)
eguma_flux = np.array([fi*1.99e-8/wi for fi, wi in zip(eguma_rates,eguma_wave)])
eguma_flux_err = (eguma_error/eguma_rates)*eguma_flux
eguma_model = np.array([fi*1.99e-8/wi for fi, wi in zip(eguma_folded,eguma_wave)])

# plt.errorbar(eguma_wave, eguma_rates, xerr=eguma_bins, yerr=eguma_error, ls='none')
# plt.plot(eguma_wave, eguma_folded)
plt.errorbar(eguma_wave, eguma_flux*1e14, xerr=eguma_bins, yerr=eguma_flux_err*1e14, ls='none', label='XMM EPIC')
plt.plot(eguma_wave, eguma_model*1e14, label='Model (phabs*(apec+apec))')
plt.xlabel('Wavelength (\AA)')
plt.ylabel('Flux (10$^{-14}$ erg s$^{-1}$ cm$^{-2}$ \AA$^{-1}$)')
plt.annotate('EG\,UMa', (0.03, 0.97), xycoords='axes fraction', ha='left', va='top')
plt.xlim(2, 55)
plt.legend()

plt.subplot(122)
for i, star in enumerate(stars):
    fx, fxel, fxeu = fluxes[i]*u.erg/u.cm**2/u.s, fluxes_el[i]*u.erg/u.cm**2/u.s, fluxes_eu[i]*u.erg/u.cm**2/u.s  
    d = dstar[i]*u.pc
    p = prot[i]*u.d
    lstar = (10**lstars[i])*u.Lsun
    lx = (4*np.pi)*(fx*(d.to(u.cm))**2).to(u.Lsun) #0.797 conversion factor from Wright+11
    lx_star = lx/lstar
    # print(lx_star)
    lx_star_err =  np.array(lx_star*[fxel/fx, fxeu/fx])
    # print(lx_star_err)
    if star == 'eguma':
        plt.errorbar(p, lx_star, yerr= [[lx_star_err[0]],[lx_star_err[1]]], marker='o', c='C4', markeredgecolor='k', label='EG\,UMa')
    else:
        plt.errorbar(p, lx_star, yerr= [[lx_star_err[0]],[lx_star_err[1]]], marker='o', c='C1', markeredgecolor='k', label='PCEBs')
#     if star == 'eguma':
#         fx = (10**-12.1730)*u.erg/u.cm**2/u.s
#         lx = (fx*(d.to(u.cm))**2).to(u.Lsun)
#         lx_star = lx/lstar
#         plt.errorbar(p, lx_star, yerr= [[lx_star_err[0]],[lx_star_err[1]]], marker='o', c='C2', markeredgecolor='k')
        
    
plt.scatter(xraydata['Prot'], 10**xraydata['Lx/bol'], marker='o', alpha=0.3, label='Wright et al. 2011')
plt.xscale('log')
plt.yscale('log')
handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys(), frameon=True)

# plt.legend()
plt.xlabel('P$_{\mathrm{rot}}$ (d)')
plt.ylabel('L$_{\mathrm{x}}$/L$_{\mathrm{bol}}$')
plt.tight_layout()
plt.savefig('../plots/eg_uma_spec_Lx_prot.png', facecolor='w')
plt.savefig('../plots/eg_uma_spec_Lx_prot.pdf', facecolor='w')

# %%
# xraydata = xraycat[1].data
# plt.figure(figsize=(7, 5))
# plt.scatter(xraydata['Prot'], 10**xraydata['Lx/bol'], marker='o', alpha=0.5)
# plt.xscale('log')
# plt.yscale('log')
# porb = 0.60417356
# porb_e = 0.00000025
# # plt.errorbar(porb, lx_strar, yerr=[[lx_r_e[0]], [lx_r_e[1]]], marker='o', ls='none', c='C1', markeredgecolor='k')
# plt.errorbar(p, lx_star, yerr= [[lx_star_err[0]],[lx_star_err[1]]], marker='o', c='C1', markeredgecolor='k')
# plt.xlabel('Porb (d)')
# plt.ylabel('R$_{\mathrm{x}}$')
# plt.tight_layout()
# # plt.savefig('plots/Rx.png', dpi=150, facecolor='w')
# # plt.savefig('plots/Rx.pdf', dpi=150, facecolor='w')

# %%
plt.figure(figsize=(8,6))
# -12.1730
print(np.log10(fluxes))

for i, star in enumerate(stars):
    fx, fxel, fxeu = fluxes[i]*u.erg/u.cm**2/u.s, fluxes_el[i]*u.erg/u.cm**2/u.s, fluxes_eu[i]*u.erg/u.cm**2/u.s  
    d = dstar[i]*u.pc
    p = prot[i]*u.d
    lstar = (10**lstars[i])*u.Lsun
    lx = (4*np.pi)*(fx*(d.to(u.cm))**2).to(u.Lsun) #0.797 conversion factor from Wright+11
    lx_star = lx/lstar
    # print(lx_star)
    lx_star_err =  np.array(lx_star*[fxel/fx, fxeu/fx])
    # print(lx_star_err)
    # if star == 'eguma':
        # plt.errorbar(p, lx_star, yerr= [[lx_star_err[0]],[lx_star_err[1]]], marker='o', c='C4', markeredgecolor='k', label='EG\,UMa')
    # else:
    plt.errorbar(p, lx_star, yerr= [[lx_star_err[0]],[lx_star_err[1]]], marker='o', c='C1', markeredgecolor='k', label='My paltry contribution')
#     if star == 'eguma':
#         fx = (10**-12.1730)*u.erg/u.cm**2/u.s
#         lx = (fx*(d.to(u.cm))**2).to(u.Lsun)
#         lx_star = lx/lstar
#         plt.errorbar(p, lx_star, yerr= [[lx_star_err[0]],[lx_star_err[1]]], marker='o', c='C2', markeredgecolor='k')
        
    
plt.scatter(xraydata['Prot'], 10**xraydata['Lx/bol'], marker='o', alpha=0.3, label='Everyone else has already done this')
plt.xscale('log')
plt.yscale('log')
handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys(), frameon=True)

# plt.legend()
plt.title('The Stellar Activity Plot')
plt.xlabel('Rotation period, or Rossby Number if you\'re feeling fancy')
plt.ylabel('Basically anything')
plt.tight_layout()
plt.savefig('../plots/joke.png', facecolor='w')
# plt.savefig('../plots/eg_uma_Lx_prot.pdf', facecolor='w')
# Out:
# [-13.53490887 -12.07850233 -12.63945644 -13.51357889 -14.19867385
#  -13.66861958 -13.49838353]

# %%
# print  (mod2.apec.kT.values)

# %%
14+ (2111/60)
# Out:
# 49.18333333333333

# %%
1800*3
# Out:
# 5400
