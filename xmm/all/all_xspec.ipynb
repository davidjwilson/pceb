# %%
import numpy as np
import matplotlib.pyplot as plt
import astropy.io.fits as fits
import os
import glob
from astropy.table import Table
from astropy.io import ascii

import astropy.units as u
from astropy import time, coordinates as coord
import astropy.constants as const
from astropy.modeling import models, fitting


#matplotlib set up
# %matplotlib inline
from matplotlib import rcParams
rcParams["figure.figsize"] = (14, 5)
rcParams["font.size"] = 20

# %%
from xspec import *
Plot.device = '/null'

# %%
glob.glob('*src_spectrum_bin10*')
# Out:
# ['v727car_src_spectrum_bin10.ds',
#  'src_spectrum_bin10.ds',
#  'wd2317+268_src_spectrum_bin10.ds',
#  'wd1448_171_src_spectrum_bin10.ds',
#  'wd1458+171_src_spectrum_bin10.ds',
#  'wd1504+546_src_spectrum_bin10.ds',
#  'wd1436-216_src_spectrum_bin10.ds']

# %%
stars = ['uzsex', 'eguma', 'eggr38', 'wd1436-216', 'wd1458+171','wd1504+546', 'v727car']
specbins = [25, 25, 25, 25, 10, 10, 10]

# %%
for i, star in enumerate(stars):
    print(star)
    
    s = Spectrum('{}_src_spectrum_bin{}.ds'.format(star, specbins[i]), backFile='{}_bkg_spectrum_grp.ds'.format(star), respFile='{}_response_grp.rmf'.format(star), arfFile='{}_EMOS1.arf'.format(star))
    # s.background = '{}_bkg_spectrum_grp.ds'.format(star)
    # s.response = '{}_response_grp.rmf'.format(star)
    # s.response.arf = '{}_EMOS1.arf'.format(star)
    
    Plot('data')
    Plot.xAxis='angstrom'
    s.ignore('**-5.0 60.0-**')
    

     
    Plot.perHz=False
    Plot.area=True
    Plot('data')

    wave = Plot.x()
    rates = Plot.y()
    bins = Plot.xErr()
    error = Plot.yErr()
    
    plt.errorbar(wave, rates, xerr=bins, yerr=error, ls='none')
    # plt.errorbar(wave, rates)
    
    mod = Model('apec*phabs', setPars={1:1, 2:0.4, 5:1e-3})
    mod.phabs.nH.frozen = True
    Fit.renorm()
    Fit.perform()
    Plot('data')
    folded = Plot.model()
    plt.plot(wave, folded)
    
    mod2 = Model('phabs*(apec+apec)', setPars={1:1e-3, 2:1,3:0.4,6:1, 7:0.4})
    mod2.phabs.nH.frozen = True
    Fit.renorm()
    Fit.perform()
    Plot('data')
    folded = Plot.model()
    plt.plot(wave, folded)

    plt.show()
    
    print('here', Fit.statistic)
    
    DataManager.clear(s)
# Out:
# uzsex
#
# 1 spectrum  in use
#
# Spectral Data File: uzsex_src_spectrum_bin25.ds  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  1.425e-02 +/- 1.830e-03 (44.6 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-14
#   Telescope: XMM Instrument: EPIC  Channel Type: PI
#   Exposure Time: 1.109e+04 sec
#  Using fit statistic: chi
#  Using Background File                bkg_spectrum_grp.ds
#   Background Exposure Time: 1.002e+04 sec
#  Using Response (RMF) File            response_grp.rmf for Source 1
#
#
# Fit statistic  : Chi-Squared                   87.74     using 14 bins.
#
# Test statistic : Chi-Squared                   87.74     using 14 bins.
#  Null hypothesis probability of 1.50e-14 with 10 degrees of freedom
#  Current data and model not fit yet.
# Net count rate (cts/s) for Spectrum:1  1.977e-02 +/- 1.779e-03 (61.9 % total)
#
# Fit statistic  : Chi-Squared                  157.54     using 14 bins.
#
# Test statistic : Chi-Squared                  157.54     using 14 bins.
#  Null hypothesis probability of 1.04e-28 with 10 degrees of freedom
#  Current data and model not fit yet.
# Response successfully loaded.
#
# Fit statistic  : Chi-Squared                  157.51     using 14 bins.
#
# Test statistic : Chi-Squared                  157.51     using 14 bins.
#  Null hypothesis probability of 1.06e-28 with 10 degrees of freedom
#  Current data and model not fit yet.
# Arf successfully loaded.
#
# Fit statistic  : Chi-Squared                   78.38     using 14 bins.
#
# Test statistic : Chi-Squared                   78.38     using 14 bins.
#  Null hypothesis probability of 1.04e-12 with 10 degrees of freedom
#  Current data and model not fit yet.
# Spectrum 1  Spectral Data File: uzsex_src_spectrum_bin25.ds
# Net count rate (cts/s) for Spectrum:1  1.977e-02 +/- 1.779e-03 (61.9 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-14
#   Telescope: XMM Instrument: EPIC  Channel Type: PI
#   Exposure Time: 1.109e+04 sec
#  Using fit statistic: chi
#  Using Background File                uzsex_bkg_spectrum_grp.ds
#   Background Exposure Time: 1.109e+04 sec
#  Using Response (RMF) File            uzsex_response_grp.rmf for Source 1
#  Using Auxiliary Response (ARF) File  uzsex_EMOS1.arf
#
#  Spectral data counts: 354
#  Model predicted rate: 2.66996E-02
#
# ***Warning: Fit is not current.
#      2 channels (13-14) ignored in spectrum #     1
#      1 channels (1) ignored in spectrum #     1
#
# Fit statistic  : Chi-Squared                   73.85     using 11 bins.
#
# Test statistic : Chi-Squared                   73.85     using 11 bins.
#  Null hypothesis probability of 2.46e-13 with 7 degrees of freedom
#  Current data and model not fit yet.
#
# ***Warning: Fit is not current.
#
# ========================================================================
# Model apec<1>*phabs<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   apec       kT         keV      1.00000      +/-  0.0
#    2    1   apec       Abundanc            1.00000      frozen
#    3    1   apec       Redshift            0.0          frozen
#    4    1   apec       norm                1.00000      +/-  0.0
#    5    2   phabs      nH         10^22    1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              8.031651e+15     using 11 bins.
#
# Test statistic : Chi-Squared              8.031651e+15     using 11 bins.
#  Null hypothesis probability of 0.000000e+00 with 8 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              6.990778e+16     using 11 bins.
#
# Test statistic : Chi-Squared              6.990778e+16     using 11 bins.
#  Null hypothesis probability of 0.000000e+00 with 8 degrees of freedom
#  Current data and model not fit yet.
#
# ========================================================================
# Model apec<1>*phabs<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   apec       kT         keV      1.00000      +/-  0.0
#    2    1   apec       Abundanc            0.400000     frozen
#    3    1   apec       Redshift            0.0          frozen
#    4    1   apec       norm                1.00000      +/-  0.0
#    5    2   phabs      nH         10^22    1.00000E-03  +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              6.990778e+16     using 11 bins.
#
# Test statistic : Chi-Squared              6.990778e+16     using 11 bins.
#  Null hypothesis probability of 0.000000e+00 with 9 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared                   55.96     using 11 bins.
#
# Test statistic : Chi-Squared                   55.96     using 11 bins.
#  Null hypothesis probability of 7.99e-09 with 9 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:kT        4:norm
# 34.1303      28.1537      -3      0.677393   3.29819e-08
# 23.7561      3.91799e+08  -4      0.612284   4.67236e-08
# 23.6962      2.63717e+07  -5      0.615888   4.74864e-08
# 23.6921      313072       -6      0.619251   4.73681e-08
# ==============================
#  Variances and Principal Axes
#                  1        4
#  1.7122E-17|  0.0000   1.0000
#  3.3142E-03|  1.0000  -0.0000
# ------------------------------
#
# ========================
#   Covariance Matrix
#         1           2
#    3.314e-03  -1.271e-10
#   -1.271e-10   2.200e-17
# ------------------------
#
# ========================================================================
# Model apec<1>*phabs<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   apec       kT         keV      0.619251     +/-  5.75693E-02
#    2    1   apec       Abundanc            0.400000     frozen
#    3    1   apec       Redshift            0.0          frozen
#    4    1   apec       norm                4.73681E-08  +/-  4.69042E-09
#    5    2   phabs      nH         10^22    1.00000E-03  frozen
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   23.69     using 11 bins.
#
# Test statistic : Chi-Squared                   23.69     using 11 bins.
#  Null hypothesis probability of 4.82e-03 with 9 degrees of freedom
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      1.00000      +/-  0.0
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              3.212661e+16     using 11 bins.
#
# Test statistic : Chi-Squared              3.212661e+16     using 11 bins.
#  Null hypothesis probability of 0.000000e+00 with 6 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              2.796311e+17     using 11 bins.
#
# Test statistic : Chi-Squared              2.796311e+17     using 11 bins.
#  Null hypothesis probability of 0.000000e+00 with 6 degrees of freedom
#  Current data and model not fit yet.
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000E-03  +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            0.400000     frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      1.00000      +/-  0.0
#    7    3   apec       Abundanc            0.400000     frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              2.796311e+17     using 11 bins.
#
# Test statistic : Chi-Squared              2.796311e+17     using 11 bins.
#  Null hypothesis probability of 0.000000e+00 with 7 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared                   55.96     using 11 bins.
#
# Test statistic : Chi-Squared                   55.96     using 11 bins.
#  Null hypothesis probability of 9.62e-10 with 7 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          2:kT        5:norm          6:kT        9:norm
# 34.1411      9.95383      -3      0.677204   1.64884e-08      0.677204   1.64884e-08
# 23.7555      2.77245e+08  -4      0.612343   2.33623e-08      0.612343   2.33623e-08
# 23.6961      1.85858e+07  -5      0.615947   2.37422e-08      0.615945   2.37422e-08
# 22.8909      217393       -5      0.756533   2.36859e-08      0.482072   2.36805e-08
# 21.887       5.45038e+07  -2      0.695807   5.10255e-08      0.145008   2.45285e-08
# 17.2179      1.26556e+08  -3      0.704158   3.70293e-08      0.202519   1.18086e-07
# 4.42054      1.93423e+08  -4      0.686676   4.05023e-08      0.162241   1.00992e-07
# 3.50283      4.8659e+07   -5      0.708653   3.67067e-08      0.156035   1.19100e-07
# 3.49701      3.39758e+06  -6      0.708879   3.68243e-08      0.155912   1.20721e-07
# ==================================================
#  Variances and Principal Axes
#                  2        5        6        9
#  1.5058E-17|  0.0000   0.9980   0.0000   0.0627
#  6.5499E-16| -0.0000  -0.0627   0.0000   0.9980
#  1.3636E-03| -0.3863  -0.0000   0.9224  -0.0000
#  7.4219E-03|  0.9224  -0.0000   0.3863  -0.0000
# --------------------------------------------------
#
# ================================================
#   Covariance Matrix
#         1           2           3           4
#    6.518e-03  -3.846e-10   2.159e-03  -2.174e-09
#   -3.846e-10   5.448e-17  -2.762e-10   2.878e-16
#    2.159e-03  -2.762e-10   2.268e-03  -2.804e-09
#   -2.174e-09   2.878e-16  -2.804e-09   4.174e-15
# ------------------------------------------------
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000E-03  frozen
#    2    2   apec       kT         keV      0.708879     +/-  8.07317E-02
#    3    2   apec       Abundanc            0.400000     frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                3.68243E-08  +/-  7.38135E-09
#    6    3   apec       kT         keV      0.155912     +/-  4.76221E-02
#    7    3   apec       Abundanc            0.400000     frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.20721E-07  +/-  6.46035E-08
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    3.50     using 11 bins.
#
# Test statistic : Chi-Squared                    3.50     using 11 bins.
#  Null hypothesis probability of 8.36e-01 with 7 degrees of freedom
# here 3.497011021059495
# eguma
#
# 1 spectrum  in use
#
# Spectral Data File: eguma_src_spectrum_bin25.ds  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  6.834e-01 +/- 2.140e-02 (97.7 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-40
#   Telescope: XMM Instrument: EPIC  Channel Type: PI
#   Exposure Time: 1528 sec
#  Using fit statistic: chi
#  Using Background File                bkg_spectrum_grp.ds
#   Background Exposure Time: 1.002e+04 sec
#  Using Response (RMF) File            response_grp.rmf for Source 1
#
#
# Fit statistic  : Chi-Squared                 1019.62     using 40 bins.
#
# Test statistic : Chi-Squared                 1019.62     using 40 bins.
#  Null hypothesis probability of 1.21e-190 with 36 degrees of freedom
#  Current data and model not fit yet.
# Net count rate (cts/s) for Spectrum:1  6.793e-01 +/- 2.148e-02 (97.1 % total)
#
# Fit statistic  : Chi-Squared                 1002.70     using 40 bins.
#
# Test statistic : Chi-Squared                 1002.70     using 40 bins.
#  Null hypothesis probability of 4.30e-187 with 36 degrees of freedom
#  Current data and model not fit yet.
# Response successfully loaded.
#
# Fit statistic  : Chi-Squared                 1002.63     using 40 bins.
#
# Test statistic : Chi-Squared                 1002.63     using 40 bins.
#  Null hypothesis probability of 4.44e-187 with 36 degrees of freedom
#  Current data and model not fit yet.
# Arf successfully loaded.
#
# Fit statistic  : Chi-Squared                  938.66     using 40 bins.
#
# Test statistic : Chi-Squared                  938.66     using 40 bins.
#  Null hypothesis probability of 1.13e-173 with 36 degrees of freedom
#  Current data and model not fit yet.
# Spectrum 1  Spectral Data File: eguma_src_spectrum_bin25.ds
# Net count rate (cts/s) for Spectrum:1  6.793e-01 +/- 2.148e-02 (97.1 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-40
#   Telescope: XMM Instrument: EPIC  Channel Type: PI
#   Exposure Time: 1528 sec
#  Using fit statistic: chi
#  Using Background File                eguma_bkg_spectrum_grp.ds
#   Background Exposure Time: 1528 sec
#  Using Response (RMF) File            eguma_response_grp.rmf for Source 1
#  Using Auxiliary Response (ARF) File  eguma_EMOS1.arf
#
#  Spectral data counts: 1069
#  Model predicted rate: 2.21552E-02
#
# ***Warning: Fit is not current.
#      2 channels (39-40) ignored in spectrum #     1
#      1 channels (1) ignored in spectrum #     1
#
# Fit statistic  : Chi-Squared                  879.92     using 37 bins.
#
# Test statistic : Chi-Squared                  879.92     using 37 bins.
#  Null hypothesis probability of 1.59e-163 with 33 degrees of freedom
#  Current data and model not fit yet.
#
# ***Warning: Fit is not current.
#
# ========================================================================
# Model apec<1>*phabs<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   apec       kT         keV      1.00000      +/-  0.0
#    2    1   apec       Abundanc            1.00000      frozen
#    3    1   apec       Redshift            0.0          frozen
#    4    1   apec       norm                1.00000      +/-  0.0
#    5    2   phabs      nH         10^22    1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              7.129522e+13     using 37 bins.
#
# Test statistic : Chi-Squared              7.129522e+13     using 37 bins.
#  Null hypothesis probability of 0.000000e+00 with 34 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              4.250335e+14     using 37 bins.
#
# Test statistic : Chi-Squared              4.250335e+14     using 37 bins.
#  Null hypothesis probability of 0.000000e+00 with 34 degrees of freedom
#  Current data and model not fit yet.
#
# ========================================================================
# Model apec<1>*phabs<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   apec       kT         keV      1.00000      +/-  0.0
#    2    1   apec       Abundanc            0.400000     frozen
#    3    1   apec       Redshift            0.0          frozen
#    4    1   apec       norm                1.00000      +/-  0.0
#    5    2   phabs      nH         10^22    1.00000E-03  +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              4.250335e+14     using 37 bins.
#
# Test statistic : Chi-Squared              4.250335e+14     using 37 bins.
#  Null hypothesis probability of 0.000000e+00 with 35 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared                  354.25     using 37 bins.
#
# Test statistic : Chi-Squared                  354.25     using 37 bins.
#  Null hypothesis probability of 1.91e-54 with 35 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:kT        4:norm
# 292.976      114.184      -3      0.831511   1.09465e-06
# 269.081      2.3566e+07   -4      0.747674   1.20064e-06
# 262.865      7.64056e+06  -5      0.702966   1.25313e-06
# 261.009      2.10124e+06  -6      0.677603   1.27816e-06
# 259.661      652924       -7      0.649040   1.30583e-06
# 259.364      95952.3      -8      0.641966   1.31260e-06
# 258.614      192711       -9      0.624714   1.33180e-06
# 258.564      296543      -10      0.619153   1.33943e-06
# 258.564      6515.13     -11      0.619185   1.33943e-06
# ==============================
#  Variances and Principal Axes
#                  1        4
#  2.6401E-15|  0.0000   1.0000
#  6.2503E-04|  1.0000  -0.0000
# ------------------------------
#
# ========================
#   Covariance Matrix
#         1           2
#    6.250e-04  -6.790e-10
#   -6.790e-10   3.378e-15
# ------------------------
#
# ========================================================================
# Model apec<1>*phabs<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   apec       kT         keV      0.619185     +/-  2.50006E-02
#    2    1   apec       Abundanc            0.400000     frozen
#    3    1   apec       Redshift            0.0          frozen
#    4    1   apec       norm                1.33943E-06  +/-  5.81181E-08
#    5    2   phabs      nH         10^22    1.00000E-03  frozen
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  258.56     using 37 bins.
#
# Test statistic : Chi-Squared                  258.56     using 37 bins.
#  Null hypothesis probability of 6.61e-36 with 35 degrees of freedom
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      1.00000      +/-  0.0
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              2.851814e+14     using 37 bins.
#
# Test statistic : Chi-Squared              2.851814e+14     using 37 bins.
#  Null hypothesis probability of 0.000000e+00 with 32 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              1.700136e+15     using 37 bins.
#
# Test statistic : Chi-Squared              1.700136e+15     using 37 bins.
#  Null hypothesis probability of 0.000000e+00 with 32 degrees of freedom
#  Current data and model not fit yet.
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000E-03  +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            0.400000     frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      1.00000      +/-  0.0
#    7    3   apec       Abundanc            0.400000     frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.700136e+15     using 37 bins.
#
# Test statistic : Chi-Squared              1.700136e+15     using 37 bins.
#  Null hypothesis probability of 0.000000e+00 with 33 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared                  354.25     using 37 bins.
#
# Test statistic : Chi-Squared                  354.25     using 37 bins.
#  Null hypothesis probability of 1.77e-55 with 33 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          2:kT        5:norm          6:kT        9:norm
# 292.959      40.3701      -3      0.831416   5.47282e-07      0.831416   5.47282e-07
# 269.081      1.66813e+07  -4      0.747672   6.00325e-07      0.747672   6.00325e-07
# 262.865      5.40197e+06  -5      0.702966   6.26564e-07      0.702966   6.26564e-07
# 261.009      1.48575e+06  -6      0.677603   6.39079e-07      0.677603   6.39079e-07
# 259.661      461685       -7      0.649040   6.52916e-07      0.649040   6.52916e-07
# 257.204      67848.3      -6      0.599712   6.56003e-07      0.684219   6.56599e-07
# 248.548      1.51814e+06   0      0.535276   6.72563e-07      0.724039   6.69689e-07
# 228.601      4.5834e+06    0      0.440503   7.25228e-07      0.777372   7.00585e-07
# 205.07       1.10006e+07   0      0.367716   8.54217e-07      0.819105   7.34875e-07
# 176.854      1.24167e+07   0      0.317986   1.06675e-06      0.852359   7.53515e-07
# Number of trials exceeded: continue fitting? 143.372      1.17687e+07   0      0.280832   1.36199e-06      0.877711   7.62296e-07
# 100.94       1.04519e+07  -1      0.187908   2.54456e-06      0.980437   7.34140e-07
# 52.7029      2.43589e+07  -2      0.203308   3.32671e-06      0.964753   8.10248e-07
# 52.3892      2.62062e+06  -3      0.202951   3.30647e-06      0.969317   7.92334e-07
# 52.3465      9159.62      -4      0.203239   3.30950e-06      0.974368   7.91809e-07
# 52.3281      52045.5      -5      0.204173   3.30290e-06      0.981735   7.90023e-07
# 52.2703      30347.3      -6      0.205373   3.28935e-06      0.987326   7.86765e-07
# 52.234       18508.6      -7      0.206471   3.27971e-06      0.990994   7.82557e-07
# 52.2245      10646        -8      0.207387   3.27204e-06      0.994100   7.79006e-07
# ==================================================
#  Variances and Principal Axes
#                  2        5        6        9
#  2.3011E-15|  0.0000   0.1258  -0.0000   0.9921
#  3.6666E-14| -0.0000  -0.9921   0.0000   0.1258
#  5.8933E-05|  0.9946  -0.0000  -0.1042  -0.0000
#  2.8620E-03| -0.1042   0.0000  -0.9946   0.0000
# --------------------------------------------------
#
# ================================================
#   Covariance Matrix
#         1           2           3           4
#    8.934e-05  -8.976e-10   2.904e-04  -3.268e-10
#   -8.976e-10   4.988e-14   7.352e-11  -6.037e-16
#    2.904e-04   7.352e-11   2.832e-03  -8.086e-10
#   -3.268e-10  -6.037e-16  -8.086e-10   4.074e-15
# ------------------------------------------------
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000E-03  frozen
#    2    2   apec       kT         keV      0.207387     +/-  9.45191E-03
#    3    2   apec       Abundanc            0.400000     frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                3.27204E-06  +/-  2.23337E-07
#    6    3   apec       kT         keV      0.994100     +/-  5.32128E-02
#    7    3   apec       Abundanc            0.400000     frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                7.79006E-07  +/-  6.38273E-08
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   52.22     using 37 bins.
#
# Test statistic : Chi-Squared                   52.22     using 37 bins.
#  Null hypothesis probability of 1.80e-02 with 33 degrees of freedom
# here 52.224506551654414
# eggr38
#
# 1 spectrum  in use
#
# Spectral Data File: eggr38_src_spectrum_bin25.ds  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  1.596e-01 +/- 3.081e-03 (89.6 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-114
#   Telescope: XMM Instrument: EPIC  Channel Type: PI
#   Exposure Time: 1.975e+04 sec
#  Using fit statistic: chi
#  Using Background File                bkg_spectrum_grp.ds
#   Background Exposure Time: 1.002e+04 sec
#  Using Response (RMF) File            response_grp.rmf for Source 1
#
#
# Fit statistic  : Chi-Squared                 2652.04     using 114 bins.
#
# Test statistic : Chi-Squared                 2652.04     using 114 bins.
#  Null hypothesis probability of 0.00e+00 with 110 degrees of freedom
#  Current data and model not fit yet.
# Net count rate (cts/s) for Spectrum:1  1.608e-01 +/- 3.042e-03 (90.3 % total)
#
# Fit statistic  : Chi-Squared                 2794.29     using 114 bins.
#
# Test statistic : Chi-Squared                 2794.29     using 114 bins.
#  Null hypothesis probability of 0.00e+00 with 110 degrees of freedom
#  Current data and model not fit yet.
# Response successfully loaded.
#
# Fit statistic  : Chi-Squared                 2799.14     using 114 bins.
#
# Test statistic : Chi-Squared                 2799.14     using 114 bins.
#  Null hypothesis probability of 0.00e+00 with 110 degrees of freedom
#  Current data and model not fit yet.
# Arf successfully loaded.
#
# Fit statistic  : Chi-Squared                28650.86     using 114 bins.
#
# Test statistic : Chi-Squared                28650.86     using 114 bins.
#  Null hypothesis probability of 0.00e+00 with 110 degrees of freedom
#  Current data and model not fit yet.
# Spectrum 1  Spectral Data File: eggr38_src_spectrum_bin25.ds
# Net count rate (cts/s) for Spectrum:1  1.608e-01 +/- 3.042e-03 (90.3 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-114
#   Telescope: XMM Instrument: EPIC  Channel Type: PI
#   Exposure Time: 1.975e+04 sec
#  Using fit statistic: chi
#  Using Background File                eggr38_bkg_spectrum_grp.ds
#   Background Exposure Time: 1.975e+04 sec
#  Using Response (RMF) File            eggr38_response_grp.rmf for Source 1
#  Using Auxiliary Response (ARF) File  eggr38_EMOS1.arf
#
#  Spectral data counts: 3516
#  Model predicted rate: 0.567277
#
# ***Warning: Fit is not current.
#      7 channels (108-114) ignored in spectrum #     1
#      1 channels (1) ignored in spectrum #     1
#
# Fit statistic  : Chi-Squared                18186.43     using 106 bins.
#
# Test statistic : Chi-Squared                18186.43     using 106 bins.
#  Null hypothesis probability of 0.00e+00 with 102 degrees of freedom
#  Current data and model not fit yet.
#
# ***Warning: Fit is not current.
#
# ========================================================================
# Model apec<1>*phabs<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   apec       kT         keV      1.00000      +/-  0.0
#    2    1   apec       Abundanc            1.00000      frozen
#    3    1   apec       Redshift            0.0          frozen
#    4    1   apec       norm                1.00000      +/-  0.0
#    5    2   phabs      nH         10^22    1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              3.413524e+15     using 106 bins.
#
# Test statistic : Chi-Squared              3.413524e+15     using 106 bins.
#  Null hypothesis probability of 0.000000e+00 with 103 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              1.805921e+16     using 106 bins.
#
# Test statistic : Chi-Squared              1.805921e+16     using 106 bins.
#  Null hypothesis probability of 0.000000e+00 with 103 degrees of freedom
#  Current data and model not fit yet.
#
# ========================================================================
# Model apec<1>*phabs<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   apec       kT         keV      1.00000      +/-  0.0
#    2    1   apec       Abundanc            0.400000     frozen
#    3    1   apec       Redshift            0.0          frozen
#    4    1   apec       norm                1.00000      +/-  0.0
#    5    2   phabs      nH         10^22    1.00000E-03  +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.805921e+16     using 106 bins.
#
# Test statistic : Chi-Squared              1.805921e+16     using 106 bins.
#  Null hypothesis probability of 0.000000e+00 with 104 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared                 1158.81     using 106 bins.
#
# Test statistic : Chi-Squared                 1158.81     using 106 bins.
#  Null hypothesis probability of 1.34e-177 with 104 degrees of freedom
#  Current data and model not fit yet.
#  renorm: no renormalization necessary
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:kT        4:norm
# 948.198      364.129      -3      0.819662   2.90299e-07
# 863.625      3.03541e+08  -4      0.731125   3.24803e-07
# 842.643      1.07048e+08  -5      0.689335   3.41839e-07
# 832.942      3.37837e+07  -6      0.661693   3.50946e-07
# 826.999      1.89306e+07  -7      0.636685   3.59431e-07
# 820.983      9.68029e+06  -8      0.604977   3.70943e-07
# 814.998      6.69354e+06  -9      0.572794   3.84692e-07
# 806.727      7.99884e+06 -10      0.539041   4.01949e-07
# 782.984      1.45581e+07 -11      0.481954   4.38755e-07
# 680.859      4.75925e+07 -12      0.362742   5.53217e-07
# Number of trials exceeded: continue fitting? 610.532      2.30221e+08 -13      0.251958   8.51926e-07
# 505.911      2.19361e+08 -14      0.265431   1.00122e-06
# 505.347      8.62344e+06 -15      0.268155   9.80651e-07
# 505.347      340292      -16      0.268212   9.80651e-07
# ==============================
#  Variances and Principal Axes
#                  1        4
#  4.0448E-16|  0.0000   1.0000
#  1.8037E-05|  1.0000  -0.0000
# ------------------------------
#
# ========================
#   Covariance Matrix
#         1           2
#    1.804e-05  -8.691e-11
#   -8.691e-11   8.232e-16
# ------------------------
#
# ========================================================================
# Model apec<1>*phabs<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   apec       kT         keV      0.268212     +/-  4.24696E-03
#    2    1   apec       Abundanc            0.400000     frozen
#    3    1   apec       Redshift            0.0          frozen
#    4    1   apec       norm                9.80651E-07  +/-  2.86923E-08
#    5    2   phabs      nH         10^22    1.00000E-03  frozen
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  505.35     using 106 bins.
#
# Test statistic : Chi-Squared                  505.35     using 106 bins.
#  Null hypothesis probability of 5.04e-54 with 104 degrees of freedom
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      1.00000      +/-  0.0
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.365410e+16     using 106 bins.
#
# Test statistic : Chi-Squared              1.365410e+16     using 106 bins.
#  Null hypothesis probability of 0.000000e+00 with 101 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              7.223686e+16     using 106 bins.
#
# Test statistic : Chi-Squared              7.223686e+16     using 106 bins.
#  Null hypothesis probability of 0.000000e+00 with 101 degrees of freedom
#  Current data and model not fit yet.
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000E-03  +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            0.400000     frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      1.00000      +/-  0.0
#    7    3   apec       Abundanc            0.400000     frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              7.223686e+16     using 106 bins.
#
# Test statistic : Chi-Squared              7.223686e+16     using 106 bins.
#  Null hypothesis probability of 0.000000e+00 with 102 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared                 1158.81     using 106 bins.
#
# Test statistic : Chi-Squared                 1158.81     using 106 bins.
#  Null hypothesis probability of 1.18e-178 with 102 degrees of freedom
#  Current data and model not fit yet.
#  renorm: no renormalization necessary
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          2:kT        5:norm          6:kT        9:norm
# 948.146      128.739      -3      0.819563   1.45139e-07      0.819563   1.45139e-07
# 863.531      2.14823e+08  -4      0.730932   1.62426e-07      0.730932   1.62426e-07
# 842.547      7.55709e+07  -5      0.688308   1.70964e-07      0.689646   1.70965e-07
# 781.232      2.37679e+07  -2      0.433638   1.75822e-07      0.886612   1.76360e-07
# 344.801      3.0638e+08   -3      0.181294   6.14659e-07      0.914473   2.72994e-07
# 180.817      9.01791e+07  -4      0.216160   9.44674e-07      0.929584   2.09576e-07
# 157.512      1.19143e+08  -5      0.212222   9.62948e-07      0.988567   1.91769e-07
# 156.589      6.10715e+06  -6      0.213103   9.67889e-07       1.01695   1.93027e-07
# 156.589      24800.3      10      0.213103   9.67889e-07       1.01695   1.93027e-07
# ==================================================
#  Variances and Principal Axes
#                  2        5        6        9
#  5.5140E-17|  0.0000   0.1259  -0.0000   0.9920
#  9.2511E-16| -0.0000  -0.9920   0.0000   0.1259
#  1.8589E-05|  0.9959  -0.0000  -0.0900  -0.0000
#  1.1448E-03| -0.0900  -0.0000  -0.9959   0.0000
# --------------------------------------------------
#
# ================================================
#   Covariance Matrix
#         1           2           3           4
#    2.771e-05  -8.983e-11   1.010e-04  -2.775e-11
#   -8.983e-11   1.359e-15   1.942e-11  -1.494e-17
#    1.010e-04   1.942e-11   1.136e-03  -9.272e-11
#   -2.775e-11  -1.494e-17  -9.272e-11   9.680e-17
# ------------------------------------------------
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000E-03  frozen
#    2    2   apec       kT         keV      0.213103     +/-  5.26445E-03
#    3    2   apec       Abundanc            0.400000     frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                9.67889E-07  +/-  3.68649E-08
#    6    3   apec       kT         keV      1.01695      +/-  3.37004E-02
#    7    3   apec       Abundanc            0.400000     frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.93027E-07  +/-  9.83887E-09
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  156.59     using 106 bins.
#
# Test statistic : Chi-Squared                  156.59     using 106 bins.
#  Null hypothesis probability of 4.17e-04 with 102 degrees of freedom
# here 156.5887169252311
# wd1436-216
#
# 1 spectrum  in use
#
# Spectral Data File: wd1436-216_src_spectrum_bin25.ds  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  1.765e-02 +/- 1.910e-03 (49.1 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-16
#   Telescope: XMM Instrument: EPIC  Channel Type: PI
#   Exposure Time: 1.136e+04 sec
#  Using fit statistic: chi
#  Using Background File                bkg_spectrum_grp.ds
#   Background Exposure Time: 1.002e+04 sec
#  Using Response (RMF) File            response_grp.rmf for Source 1
#
#
# Fit statistic  : Chi-Squared                  108.74     using 16 bins.
#
# Test statistic : Chi-Squared                  108.74     using 16 bins.
#  Null hypothesis probability of 1.06e-17 with 12 degrees of freedom
#  Current data and model not fit yet.
# Net count rate (cts/s) for Spectrum:1  1.992e-02 +/- 1.780e-03 (55.5 % total)
#
# Fit statistic  : Chi-Squared                  153.07     using 16 bins.
#
# Test statistic : Chi-Squared                  153.07     using 16 bins.
#  Null hypothesis probability of 1.35e-26 with 12 degrees of freedom
#  Current data and model not fit yet.
# Response successfully loaded.
#
# Fit statistic  : Chi-Squared                  153.08     using 16 bins.
#
# Test statistic : Chi-Squared                  153.08     using 16 bins.
#  Null hypothesis probability of 1.35e-26 with 12 degrees of freedom
#  Current data and model not fit yet.
# Arf successfully loaded.
#
# Fit statistic  : Chi-Squared                 9600.09     using 16 bins.
#
# Test statistic : Chi-Squared                 9600.09     using 16 bins.
#  Null hypothesis probability of 0.00e+00 with 12 degrees of freedom
#  Current data and model not fit yet.
# Spectrum 1  Spectral Data File: wd1436-216_src_spectrum_bin25.ds
# Net count rate (cts/s) for Spectrum:1  1.992e-02 +/- 1.780e-03 (55.5 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-16
#   Telescope: XMM Instrument: EPIC  Channel Type: PI
#   Exposure Time: 1.136e+04 sec
#  Using fit statistic: chi
#  Using Background File                wd1436-216_bkg_spectrum_grp.ds
#   Background Exposure Time: 1.133e+04 sec
#  Using Response (RMF) File            wd1436-216_response_grp.rmf for Source 1
#  Using Auxiliary Response (ARF) File  wd1436-216_EMOS1.arf
#
#  Spectral data counts: 408
#  Model predicted rate: 0.164001
#
# ***Warning: Fit is not current.
#      3 channels (14-16) ignored in spectrum #     1
#      1 channels (1) ignored in spectrum #     1
#
# Fit statistic  : Chi-Squared                 8163.97     using 12 bins.
#
# Test statistic : Chi-Squared                 8163.97     using 12 bins.
#  Null hypothesis probability of 0.00e+00 with 8 degrees of freedom
#  Current data and model not fit yet.
#
# ***Warning: Fit is not current.
#
# ========================================================================
# Model apec<1>*phabs<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   apec       kT         keV      1.00000      +/-  0.0
#    2    1   apec       Abundanc            1.00000      frozen
#    3    1   apec       Redshift            0.0          frozen
#    4    1   apec       norm                1.00000      +/-  0.0
#    5    2   phabs      nH         10^22    1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              7.338278e+15     using 12 bins.
#
# Test statistic : Chi-Squared              7.338278e+15     using 12 bins.
#  Null hypothesis probability of 0.000000e+00 with 9 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              6.990910e+16     using 12 bins.
#
# Test statistic : Chi-Squared              6.990910e+16     using 12 bins.
#  Null hypothesis probability of 0.000000e+00 with 9 degrees of freedom
#  Current data and model not fit yet.
#
# ========================================================================
# Model apec<1>*phabs<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   apec       kT         keV      1.00000      +/-  0.0
#    2    1   apec       Abundanc            0.400000     frozen
#    3    1   apec       Redshift            0.0          frozen
#    4    1   apec       norm                1.00000      +/-  0.0
#    5    2   phabs      nH         10^22    1.00000E-03  +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              6.990910e+16     using 12 bins.
#
# Test statistic : Chi-Squared              6.990910e+16     using 12 bins.
#  Null hypothesis probability of 0.000000e+00 with 10 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared                   62.34     using 12 bins.
#
# Test statistic : Chi-Squared                   62.34     using 12 bins.
#  Null hypothesis probability of 1.31e-09 with 10 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:kT        4:norm
# 57.6327      10.1601      -3      0.887192   3.39764e-08
# 52.6297      6.81288e+07  -4      0.770959   3.52331e-08
# 51.215       6.64837e+07  -5      0.717071   3.75110e-08
# 51.0487      1.82456e+07  -6      0.694523   3.84725e-08
# 51.0486      359808       -7      0.695086   3.84725e-08
# ==============================
#  Variances and Principal Axes
#                  1        4
#  1.4278E-17|  0.0000   1.0000
#  3.1969E-03|  1.0000  -0.0000
# ------------------------------
#
# ========================
#   Covariance Matrix
#         1           2
#    3.197e-03  -5.828e-11
#   -5.828e-11   1.534e-17
# ------------------------
#
# ========================================================================
# Model apec<1>*phabs<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   apec       kT         keV      0.695086     +/-  5.65413E-02
#    2    1   apec       Abundanc            0.400000     frozen
#    3    1   apec       Redshift            0.0          frozen
#    4    1   apec       norm                3.84725E-08  +/-  3.91667E-09
#    5    2   phabs      nH         10^22    1.00000E-03  frozen
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   51.05     using 12 bins.
#
# Test statistic : Chi-Squared                   51.05     using 12 bins.
#  Null hypothesis probability of 1.71e-07 with 10 degrees of freedom
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      1.00000      +/-  0.0
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              2.935311e+16     using 12 bins.
#
# Test statistic : Chi-Squared              2.935311e+16     using 12 bins.
#  Null hypothesis probability of 0.000000e+00 with 7 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              2.796364e+17     using 12 bins.
#
# Test statistic : Chi-Squared              2.796364e+17     using 12 bins.
#  Null hypothesis probability of 0.000000e+00 with 7 degrees of freedom
#  Current data and model not fit yet.
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000E-03  +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            0.400000     frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      1.00000      +/-  0.0
#    7    3   apec       Abundanc            0.400000     frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              2.796364e+17     using 12 bins.
#
# Test statistic : Chi-Squared              2.796364e+17     using 12 bins.
#  Null hypothesis probability of 0.000000e+00 with 8 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared                   62.34     using 12 bins.
#
# Test statistic : Chi-Squared                   62.34     using 12 bins.
#  Null hypothesis probability of 1.62e-10 with 8 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          2:kT        5:norm          6:kT        9:norm
# 57.6298      3.59215      -3      0.887116   1.69868e-08      0.887116   1.69868e-08
# 52.6294      4.8259e+07   -4      0.770947   1.76166e-08      0.770947   1.76166e-08
# 51.2147      4.70137e+07  -5      0.717058   1.87558e-08      0.717055   1.87558e-08
# 51.0487      1.28968e+07  -6      0.694525   1.92363e-08      0.694522   1.92363e-08
# 51.0486      254100       -7      0.695088   1.92363e-08      0.695085   1.92363e-08
# ==================================================
#  Variances and Principal Axes
#                  2        5        6        9
#  6.1790E-04|  0.0065   1.0000   0.0065   0.0000
#  6.1790E-02| -0.0000   0.0000  -0.0000   1.0000
#  8.8770E+07| -0.7071   0.0092  -0.7071  -0.0000
# ...
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            0.400000     frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      1.00000      +/-  0.0
#    7    3   apec       Abundanc            0.400000     frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              3.110877e+16     using 7 bins.
#
# Test statistic : Chi-Squared              3.110877e+16     using 7 bins.
#  Null hypothesis probability of 0.000000e+00 with 3 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared                    6.93     using 7 bins.
#
# Test statistic : Chi-Squared                    6.93     using 7 bins.
#  Null hypothesis probability of 7.40e-02 with 3 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          2:kT        5:norm          6:kT        9:norm
# 6.10293      0.296757     -3      0.655034   9.25034e-09      0.655034   9.25034e-09
# 5.63211      3.84588e+07  -4      0.249019   2.47746e-08      0.249019   2.47746e-08
# 2.07745      1.84888e+07  -5      0.301033   5.31308e-08      0.301033   5.31308e-08
# 1.69281      6.67121e+06  -6      0.273465   5.31485e-08      0.273465   5.31485e-08
# 1.69275      72365.8      -7      0.273074   5.33799e-08      0.273015   5.33796e-08
# ***Warning: LevMarq::invertCorrelationMatrix:
#             Negative diagonal element for parameter 2
# ***Warning: LevMarq::invertCorrelationMatrix:
#             Negative diagonal element for parameter 5
# ***Warning: LevMarq::invertCorrelationMatrix:
#             Negative diagonal element for parameter 6
# ***Warning: LevMarq::invertCorrelationMatrix:
#             Negative diagonal element for parameter 9
# ==================================================
#  Variances and Principal Axes
#                  2        5        6        9
#  1.0300E+05|  0.7071  -0.0000  -0.7071   0.0000
#  1.0300E+05| -0.4998  -0.7074  -0.4998  -0.0000
#  1.0300E+05| -0.0000  -0.0000   0.0000   1.0000
#  1.0300E+07|  0.5002  -0.7068   0.5002   0.0000
# --------------------------------------------------
#
# ================================================
#   Covariance Matrix
#         1           2           3           4
#   -3.709e+13   4.185e+07   3.709e+13  -4.185e+07
#    2.730e+07  -2.020e+01  -2.730e+07   2.020e+01
#    3.709e+13  -4.185e+07  -3.709e+13   4.185e+07
#   -2.730e+07   2.020e+01   2.730e+07  -2.020e+01
# ------------------------------------------------
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000E-03  frozen
#    2    2   apec       kT         keV      0.273074     +/-  -1.00000
#    3    2   apec       Abundanc            0.400000     frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                5.33799E-08  +/-  -1.00000
#    6    3   apec       kT         keV      0.273015     +/-  -1.00000
#    7    3   apec       Abundanc            0.400000     frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                5.33796E-08  +/-  -1.00000
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                    1.69     using 7 bins.
#
# Test statistic : Chi-Squared                    1.69     using 7 bins.
#  Null hypothesis probability of 6.39e-01 with 3 degrees of freedom
# here 1.692748518620913
# v727car
#
# 1 spectrum  in use
#
# Spectral Data File: v727car_src_spectrum_bin10.ds  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  2.597e-02 +/- 2.786e-03 (58.4 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-26
#   Telescope: XMM Instrument: EPIC  Channel Type: PI
#   Exposure Time: 6116 sec
#  Using fit statistic: chi
#  Using Background File                bkg_spectrum_grp.ds
#   Background Exposure Time: 1.002e+04 sec
#  Using Response (RMF) File            response_grp.rmf for Source 1
#
#
# Fit statistic  : Chi-Squared                  108.66     using 26 bins.
#
# Test statistic : Chi-Squared                  108.66     using 26 bins.
#  Null hypothesis probability of 1.91e-13 with 22 degrees of freedom
#  Current data and model not fit yet.
# Net count rate (cts/s) for Spectrum:1  3.076e-02 +/- 2.698e-03 (69.2 % total)
#
# Fit statistic  : Chi-Squared                  151.85     using 26 bins.
#
# Test statistic : Chi-Squared                  151.85     using 26 bins.
#  Null hypothesis probability of 2.14e-21 with 22 degrees of freedom
#  Current data and model not fit yet.
# Response successfully loaded.
#
# Fit statistic  : Chi-Squared                  151.94     using 26 bins.
#
# Test statistic : Chi-Squared                  151.94     using 26 bins.
#  Null hypothesis probability of 2.06e-21 with 22 degrees of freedom
#  Current data and model not fit yet.
# Arf successfully loaded.
#
# Fit statistic  : Chi-Squared                   53.14     using 26 bins.
#
# Test statistic : Chi-Squared                   53.14     using 26 bins.
#  Null hypothesis probability of 2.17e-04 with 22 degrees of freedom
#  Current data and model not fit yet.
# Spectrum 1  Spectral Data File: v727car_src_spectrum_bin10.ds
# Net count rate (cts/s) for Spectrum:1  3.076e-02 +/- 2.698e-03 (69.2 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-26
#   Telescope: XMM Instrument: EPIC  Channel Type: PI
#   Exposure Time: 6116 sec
#  Using fit statistic: chi
#  Using Background File                v727car_bkg_spectrum_grp.ds
#   Background Exposure Time: 6102 sec
#  Using Response (RMF) File            v727car_response_grp.rmf for Source 1
#  Using Auxiliary Response (ARF) File  v727car_EMOS1.arf
#
#  Spectral data counts: 272
#  Model predicted rate: 1.44929E-02
#
# ***Warning: Fit is not current.
#      5 channels (22-26) ignored in spectrum #     1
#      1 channels (1) ignored in spectrum #     1
#
# Fit statistic  : Chi-Squared                   43.91     using 20 bins.
#
# Test statistic : Chi-Squared                   43.91     using 20 bins.
#  Null hypothesis probability of 2.03e-04 with 16 degrees of freedom
#  Current data and model not fit yet.
#
# ***Warning: Fit is not current.
#
# ========================================================================
# Model apec<1>*phabs<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   apec       kT         keV      1.00000      +/-  0.0
#    2    1   apec       Abundanc            1.00000      frozen
#    3    1   apec       Redshift            0.0          frozen
#    4    1   apec       norm                1.00000      +/-  0.0
#    5    2   phabs      nH         10^22    1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              3.912382e+15     using 20 bins.
#
# Test statistic : Chi-Squared              3.912382e+15     using 20 bins.
#  Null hypothesis probability of 0.000000e+00 with 17 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              3.175220e+16     using 20 bins.
#
# Test statistic : Chi-Squared              3.175220e+16     using 20 bins.
#  Null hypothesis probability of 0.000000e+00 with 17 degrees of freedom
#  Current data and model not fit yet.
#
# ========================================================================
# Model apec<1>*phabs<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   apec       kT         keV      1.00000      +/-  0.0
#    2    1   apec       Abundanc            0.400000     frozen
#    3    1   apec       Redshift            0.0          frozen
#    4    1   apec       norm                1.00000      +/-  0.0
#    5    2   phabs      nH         10^22    1.00000E-03  +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              3.175220e+16     using 20 bins.
#
# Test statistic : Chi-Squared              3.175220e+16     using 20 bins.
#  Null hypothesis probability of 0.000000e+00 with 18 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared                   81.78     using 20 bins.
#
# Test statistic : Chi-Squared                   81.78     using 20 bins.
#  Null hypothesis probability of 4.17e-10 with 18 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          1:kT        4:norm
# 59.8005      22.1102      -3      0.613253   3.98023e-08
# 40.0452      3.09751e+08  -4      0.412592   7.70150e-08
# 38.4443      1.28564e+08  -2      0.252272   1.32924e-07
# 24.0362      9.88546e+07  -3      0.277515   1.81624e-07
# 23.9385      9.63297e+06  -4      0.276922   1.77124e-07
# 23.9385      25648.7      -5      0.276908   1.77123e-07
# ==============================
#  Variances and Principal Axes
#                  1        4
#  2.6235E-16|  0.0000   1.0000
#  4.2200E-04|  1.0000  -0.0000
# ------------------------------
#
# ========================
#   Covariance Matrix
#         1           2
#    4.220e-04  -3.642e-10
#   -3.642e-10   5.766e-16
# ------------------------
#
# ========================================================================
# Model apec<1>*phabs<2> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   apec       kT         keV      0.276908     +/-  2.05427E-02
#    2    1   apec       Abundanc            0.400000     frozen
#    3    1   apec       Redshift            0.0          frozen
#    4    1   apec       norm                1.77123E-07  +/-  2.40126E-08
#    5    2   phabs      nH         10^22    1.00000E-03  frozen
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   23.94     using 20 bins.
#
# Test statistic : Chi-Squared                   23.94     using 20 bins.
#  Null hypothesis probability of 1.57e-01 with 18 degrees of freedom
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      1.00000      +/-  0.0
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.564953e+16     using 20 bins.
#
# Test statistic : Chi-Squared              1.564953e+16     using 20 bins.
#  Null hypothesis probability of 0.000000e+00 with 15 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared              1.270088e+17     using 20 bins.
#
# Test statistic : Chi-Squared              1.270088e+17     using 20 bins.
#  Null hypothesis probability of 0.000000e+00 with 15 degrees of freedom
#  Current data and model not fit yet.
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000E-03  +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            0.400000     frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      1.00000      +/-  0.0
#    7    3   apec       Abundanc            0.400000     frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared              1.270088e+17     using 20 bins.
#
# Test statistic : Chi-Squared              1.270088e+17     using 20 bins.
#  Null hypothesis probability of 0.000000e+00 with 16 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared                   81.78     using 20 bins.
#
# Test statistic : Chi-Squared                   81.78     using 20 bins.
#  Null hypothesis probability of 7.92e-11 with 16 degrees of freedom
#  Current data and model not fit yet.
#                                    Parameters
# Chi-Squared  |beta|/N    Lvl          2:kT        5:norm          6:kT        9:norm
# 59.8096      7.81712      -3      0.613047   1.98990e-08      0.613047   1.98990e-08
# 40.0504      2.19111e+08  -4      0.412071   3.85340e-08      0.412071   3.85340e-08
# 31.0152      9.10346e+07  -1      0.301689   6.06558e-08      0.301689   6.06558e-08
# 24.2431      6.05491e+07  -2      0.271832   8.66130e-08      0.271832   8.66130e-08
# 23.9459      1.06583e+07  -3      0.275158   8.93387e-08      0.275156   8.93387e-08
# 23.9385      55521.1      -4      0.280904   8.85862e-08      0.272772   8.85830e-08
# ***Warning: LevMarq::invertCorrelationMatrix:
#             Negative diagonal element for parameter 5
# ***Warning: LevMarq::invertCorrelationMatrix:
#             Negative diagonal element for parameter 9
# ==================================================
#  Variances and Principal Axes
#                  2        5        6        9
#  6.8516E-05|  0.7071  -0.0765   0.6988   0.0761
#  6.8516E-05| -0.0538   0.0033  -0.0538   0.9971
#  6.8516E-03| -0.0541  -0.9971  -0.0541  -0.0026
#  2.8403E+06|  0.7030   0.0004  -0.7112  -0.0004
# --------------------------------------------------
#
# ================================================
#   Covariance Matrix
#         1           2           3           4
#    1.404e+06   9.062e+02  -1.420e+06  -9.062e+02
#    9.063e+02  -7.926e-01  -8.917e+02   7.926e-01
#   -1.420e+06  -8.916e+02   1.437e+06   8.916e+02
#   -9.063e+02   7.926e-01   8.917e+02  -7.926e-01
# ------------------------------------------------
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000E-03  frozen
#    2    2   apec       kT         keV      0.280904     +/-  1184.70
#    3    2   apec       Abundanc            0.400000     frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                8.85862E-08  +/-  -1.00000
#    6    3   apec       kT         keV      0.272772     +/-  1198.58
#    7    3   apec       Abundanc            0.400000     frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                8.85830E-08  +/-  -1.00000
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                   23.94     using 20 bins.
#
# Test statistic : Chi-Squared                   23.94     using 20 bins.
#  Null hypothesis probability of 9.09e-02 with 16 degrees of freedom
# here 23.938508728256224

# %%
# plt.errorbar(wave, rates, xerr=bins, yerr=error, ls='none')

# %%
# # s.ignore('bad')
# Plot.xAxis='angstrom'
# s.ignore('**-5.0 60.0-**')

# mod = Model('phabs*(apec+apec)', setPars={1:1e-3, 2:0.5,3:0.4,6:2.0, 7:0.4})
# # mod.phabs.nH.frozen = True
# # mod.apec.Abundanc.frozen = False
# # mod.apec_3.Abundanc.frozen = False

# AllModels.setEnergies("0.3 10")
# Fit.perform()
# flux = AllModels.calcFlux(".3 10 err")
# print(flux)


# # Plot.setRebin(minSig=3, maxBins=10, groupNum=1, errType='quad')

# Plot.perHz=False
# Plot.area=True
# Plot('data')

# wave = Plot.x()
# rates = Plot.y()
# bins = Plot.xErr()
# error = Plot.yErr()
# folded = Plot.model()
# plt.errorbar(wave, rates, xerr=bins, yerr=error, ls='none')
# # plt.step(wave, rates, where='mid')
# plt.plot(wave, folded)

# flux = AllModels.calcFlux(".3 10 err")
# print(flux)

# %%
# flux = AllModels.calcFlux(".3 10 err")
# print(flux)

# %%
s.flux
# Out:
# (1.8699871054245658e-13,
#  1.770236138536613e-13,
#  1.8847416256346974e-13,
#  0.00016630192792586754,
#  0.00015635778302308632,
#  0.00016645113071537613)

# %%
# fx, fxel, fxeu = s.flux[0]*u.erg/u.cm**2/u.s, (s.flux[0]-s.flux[1])*u.erg/u.cm**2/u.s, (s.flux[2]-s.flux[0])*u.erg/u.cm**2/u.s  
# d = (1000/23.39160255904337)*u.pc
# p = 0.56*u.d
# lstar = (10**-2.5)*u.Lsun
# lx = (fx*(d.to(u.cm))**2).to(u.Lsun)
# lx_star = lx/lstar
# print(lx_star)
# lx_star_err =  np.array(lx_star*[fxel/fx, fxeu/fx])
# print(lx_star_err)
# Out:
# 0.0002688114852681345
# [1.43392462e-05 2.12096890e-06]

# %%
# path = '/media/david/2tb_ext_hd/hddata/carmenes_binary/xraycat/'
# xraycat = fits.open('{}J_ApJ_743_48_catalog.dat.fits'.format(path))

# %%
# xraydata = xraycat[1].data
# plt.figure(figsize=(7, 5))
# plt.scatter(xraydata['Prot'], 10**xraydata['Lx/bol'], marker='o', alpha=0.5)
# plt.xscale('log')
# plt.yscale('log')
# porb = 0.60417356
# porb_e = 0.00000025
# # plt.errorbar(porb, lx_strar, yerr=[[lx_r_e[0]], [lx_r_e[1]]], marker='o', ls='none', c='C1', markeredgecolor='k')
# plt.errorbar(p, lx_star, yerr= [[lx_star_err[0]],[lx_star_err[1]]], marker='o', c='C1', markeredgecolor='k')
# plt.xlabel('Porb (d)')
# plt.ylabel('R$_{\mathrm{x}}$')
# plt.tight_layout()
# # plt.savefig('plots/Rx.png', dpi=150, facecolor='w')
# # plt.savefig('plots/Rx.pdf', dpi=150, facecolor='w')

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_44450/587308377.py in <module>
# ----> 1 mod.statistic
#
# AttributeError: 'Model' object has no attribute 'statistic'
