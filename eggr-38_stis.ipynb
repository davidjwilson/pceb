# %% [markdown]
# Coadding the STIS E140M for EGGR-38.

# %%
import numpy as np
import matplotlib.pyplot as plt
import astropy.io.fits as fits
import os
import glob
from astropy.table import Table
from astropy.io import ascii
from astropy.convolution import convolve, Box1DKernel, Gaussian1DKernel
from scipy.interpolate import interp1d

import astropy.units as u
from astropy import time, coordinates as coord
import astropy.constants as const
from astropy.modeling import models, fitting
from astropy.coordinates import SkyCoord
from matplotlib.gridspec import GridSpec
from datetime import datetime
from mpl_toolkits.axes_grid1.inset_locator import inset_axes


#matplotlib set up
# %matplotlib inline
from matplotlib import rcParams
rcParams["figure.figsize"] = (14, 5)
rcParams["font.size"] = 20

# %%
path = '/home/david/work/stisFix/output/eggr38/'
specs = glob.glob('{}*.dat'.format(path))
specs
# Out:
# ['/home/david/work/stisFix/output/eggr38/o5dma8010_spliced.dat',
#  '/home/david/work/stisFix/output/eggr38/o5dma5010_spliced.dat',
#  '/home/david/work/stisFix/output/eggr38/o5dma7010_spliced.dat',
#  '/home/david/work/stisFix/output/eggr38/o5dma6010_spliced.dat']

# %%
for spec in specs:
    w, f, e = np.loadtxt(spec, unpack=True)
    mask = w > 1160
    plt.plot(w[mask], f[mask])
    plt.plot(w[mask], e[mask])
    plt.xlim(1210, 1220)
    plt.show()

# %% [markdown]
# checking where the orders are

# %%
x1ds  = glob.glob('/media/david/2tb_ext_hd/hddata/pcebs/hst/stis/eggr38/*x1f.fits')
x1ds
# Out:
# ['/media/david/2tb_ext_hd/hddata/pcebs/hst/stis/eggr38/o5dma5010_x1f.fits',
#  '/media/david/2tb_ext_hd/hddata/pcebs/hst/stis/eggr38/o5dma6010_x1f.fits',
#  '/media/david/2tb_ext_hd/hddata/pcebs/hst/stis/eggr38/o5dma7010_x1f.fits',
#  '/media/david/2tb_ext_hd/hddata/pcebs/hst/stis/eggr38/o5dma8010_x1f.fits']

# %%
for x in x1ds:
    data = fits.getdata(x, 1)
    for dt in data[::-1]:
        # plt.step(dt['WAVELENGTH'], dt['FLUX'], where='mid')
        # plt.step(dt['WAVELENGTH'], dt['GROSS'], where='mid')
        # plt.step(dt['WAVELENGTH'], dt['GROSS'], where='mid')
        plt.step(dt['WAVELENGTH'], dt['GROSS']/dt['BACKGROUND'], where='mid')
        # plt.step(dt['WAVELENGTH'], dt['NET'], where='mid')
    plt.xlim(1210, 1220)
    plt.ylim(0, 20)
    # plt.ylim(-0.1e-13, 7e-13)
    plt.show()

# %%
#rvs from https://ui.adsabs.harvard.edu/abs/1987AJ.....94..996S/abstract
gamma = 36.7*u.km/u.s
k = 124.3*u.km/u.s

lya = 1215.67

plt.figure(figsize=(18, 5))

for i, spec in enumerate(specs):
    plt.subplot(1, 4, i+1)
    w, f, e = np.loadtxt(spec, unpack=True)
    mask = w > 1160
    w, f, e  = w[mask], f[mask], e[mask]
    v = (w*u.AA).to(u.km/u.s,  equivalencies=u.doppler_optical(lya*u.AA))
    plt.step(v, f, where='mid')
    plt.xlim(-499, 499)

    # plt.plot(w[mask], f[mask])
    # plt.plot(w[mask], e[mask])
    # plt.xlim(1210, 1220)
    plt.ylim(-0.5e-13, 4e-13)
    plt.axvline((gamma+k).value, ls='--', c='C2')
    plt.axvline((gamma-k).value, ls='--', c='C2')
    # plt.show()

# %%
for spec in specs:
    w, f, e = np.loadtxt(spec, unpack=True)
    mask = w > 1160
    w, f, e  = w[mask], f[mask], e[mask]
    plt.step(w,f, where='mid')
    plt.show()
